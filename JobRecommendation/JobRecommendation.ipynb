# %%
'''
This script is the main body of Job Recommendation function.
Input:
    1. Database of jobs
    2. Profile of one candidate
    3. Recommendation options
Components:
    1. Hard skill matching
    2. Soft skill matching
    3. Language matching
    4. Location matching
    5. Integration and ranking
Ouput: Job ranking
'''
# Out:
# '\nThis script is the main body of Job Recommendation function.\nInput:\n    1. Database of jobs\n    2. Profile of one candidate\n    3. Recommendation options\nComponents:\n    1. Hard skill matching\n    2. Soft skill matching\n    3. Language matching\n    4. Location matching\n    5. Integration and ranking\nOuput: Job ranking\n'

# %%
import json
import math
import numpy as np
import pandas as pd

# %%
def angle(x):
    return x * math.pi / 180

# %%
# modify options
HARD = True
SOFT = True
LANG = True
LOC = True

# %%
# modify weights as
HARD_WEIGHT = 1
SOFT_WEIGHT = 0.25
LANG_WEIGHT = 0.5
LOC_WEIGHT = 0.25
BETA = 1  # parameter in F-beta score

# %%
# insert data
jobs = pd.read_json("support/data.json")
candidate = {'hard skills': ['python', 'linux', 'c'],
             'soft skills': ['analytical skill'],
             'languages': ['cantonese', 'english'],
             'location': 'Sha Tin'
             }

# %%
# match hard skills
hard_score = []
cs = candidate['hard skills']
for r in jobs['requirements']:
    js = r['hard_skills']
    tp = len(set(cs) & set(js))
    if tp != 0:
        precision = tp / len(set(cs))
        recall = tp / len(set(js))
        f = (1 + BETA ** 2) * precision * recall / (BETA ** 2 * precision + recall)
        hard_score.append(f)
    else: hard_score.append(0)
hard_score = np.array(hard_score)
hard_score /= max(hard_score)

# %%
# match soft skills
soft_score = []
cs = candidate['soft skills']
for r in jobs['requirements']:
    js = r['soft_skills']
    tp = len(set(cs) & set(js))
    if tp != 0:
        precision = tp / len(set(cs))
        recall = tp / len(set(js))
        f = (1 + BETA ** 2) * precision * recall / (BETA ** 2 * precision + recall)
        soft_score.append(f)
    else: soft_score.append(0)
soft_score = np.array(soft_score)
soft_score /= max(soft_score)

# %%
# match languages
f = open("support/language_info.json")
lang_info = json.load(f)
lang_map = {}
impl_map = {}
for d in lang_info:
    for a in d['aliases']: lang_map[a] = d['language']
    for i in d['implications']:
        if d['language'] in impl_map: impl_map[d['language']].append(i)
        else: impl_map[d['language']] = [i]

lang_score = []
cl = candidate['languages']
for i in range(len(cl)):
    l = cl[i]
    if l in lang_map: cl[i] = lang_map[l]
    if l in impl_map:
        for L in impl_map[l]:
            if not L in cl: cl.append(L)

for r in jobs['requirements']:
    jl = r['languages']
    tp = len(set(cl) & set(jl))
    if tp != 0:
        precision = tp / len(set(cl))
        recall = tp / len(set(jl))
        f = (1 + BETA ** 2) * precision * recall / (BETA ** 2 * precision + recall)
        lang_score.append(f)
    else: lang_score.append(0)
lang_score = np.array(lang_score)
lang_score /= max(lang_score)

# %%
# match location
f = open("support/location_info.json")
loc_info = json.load(f)
loc_map = {}
for d in loc_info:
    for l in d['locations']: loc_map[l] = d['district']
coordinate = {d['district']: d['coordinate'] for d in loc_info}
f.close()

loc_score = []
cl = candidate['location']
if not cl in coordinate:
    if cl in loc_map: cl = loc_map[cl]
    else: cl = 'Others'

if cl == 'Others': loc_score = [0 for i in range(len(jobs))]
else:
    dist_map = {}
    v1 = (math.cos(angle(coordinate[cl][0])) * math.cos(angle(coordinate[cl][1])),
          math.cos(angle(coordinate[cl][0])) * math.sin(angle(coordinate[cl][1])),
          math.sin(angle(coordinate[cl][0])))
    for k, v in coordinate.items():
        v2 = (math.cos(angle(v[0])) * math.cos(angle(v[1])),
              math.cos(angle(v[0])) * math.sin(angle(v[1])),
              math.sin(angle(v[0])))
        dist_map[k] = 1 - np.dot(v1, v2)

    for jl in jobs['locations']:
        if jl == 'Others': loc_score.append(-1)
        else: loc_score.append(dist_map[jl])
    scale = max(loc_score)
    for i in range(len(loc_score)):
        if loc_score[i] != -1: loc_score[i] = 1 - loc_score[i] / scale
        else: loc_score[i] = 0

# %%
# integrate and rank
if not HARD: HARD_WEIGHT = 0
if not SOFT: SOFT_WEIGHT = 0
if not LANG: LANG_WEIGHT = 0
if not LOC: LOC_WEIGHT = 0

intg_score = HARD_WEIGHT * hard_score +\
             SOFT_WEIGHT * soft_score +\
             LANG_WEIGHT * lang_score +\
             [LOC_WEIGHT * s for s in loc_score]
jobs['hard_skill_score'] = hard_score
jobs['soft_skill_score'] = soft_score
jobs['language_score'] = lang_score
jobs['location_score'] = loc_score
jobs['integrated_score'] = intg_score
jobs = jobs.sort_values('integrated_score', ascending=False)

# %%
# output
jobs
# Out:
#                 job_id location_code                                  company  \
# 10748  100003009055333            hk                            Computime Ltd
# 10731  100003009054494            hk                    Open Creative Limited
# 11195  100003009031583            hk  Gientech Technology (Hong Kong) Limited
# 13721  100003009047669            hk              The University of Hong Kong
# 17225  100003009056020            hk         VTech Telecommunications Limited
# ...                ...           ...                                      ...
# 5309   100003009051592            hk                     RecruitFirst Limited
# 5314   100003009045774            hk               Randstad Hong Kong Limited
# 17519  100003009055593            hk                      Robert Walters (HK)
# 5330   100003009043841            hk             CODALAB INTERNATIONAL CO LTD
# 9849   100003009045603            hk   Temptation Taste Confectionery Limited
#
#                                                job_title  \
# 10748                         Senior Engineer - Software
# 10731                          Full Stack Web Developers
# 11195                System Specialist (Linux / Windows)
# 13721      Part-time Student Research Assistant (509080)
# 17225  Senior Software Engineer – IoT Product Develop...
# ...                                                  ...
# 5309   德國知名相機品牌售貨員 Senior/Sales Advisor (首三個月包薪/23K+/...
# 5314                                 Merchandise Planner
# 17519     Site Supervisor (ELV, 30K, 5-day, Client side)
# 5330                                Sales Associates 售貨員
# 9849                                         店務助理(馬鞍山分店)
#
#                                              description  \
# 10748  Major Responsibilities\n\nDesign, code, and de...
# 10731  Major Responsibilities\n\nDesign, code, and de...
# 11195  About us\n\nGientech is a global company offer...
# 13721  Part-time Student Research Assistant in the Sc...
# 17225  We are expanding our research and development ...
# ...                                                  ...
# 5309   主要職責:\n\n推廣及銷售各種高級相機，以達致店鋪銷售目標\n提供專業意見並教授客人攝影技...
# 5314   about the company.\nOur client is a leading fa...
# 17519  We are searching for a Site Supervisor for our...
# 5330   人氣飾物品牌, 現邀請充滿活力的你加入我們的工作團隊。\n\nwww.codalab.co\...
# 9849   條件\n\n中學會考中文及英文 (課程乙) 合格或中學文憑考試同等等級\n熟悉中英文電腦文書...
#
#              employment_types  \
# 10748  [Full Time, Permanent]
# 10731  [Full Time, Permanent]
# 11195  [Full Time, Permanent]
# 13721             [Part Time]
# 17225  [Full Time, Permanent]
# ...                       ...
# 5309              [Full Time]
# 5314   [Full Time, Permanent]
# 17519  [Full Time, Temporary]
# 5330              [Full Time]
# 9849              [Full Time]
#
#                                           selling_points        locations  \
# 10748  [5 days work, double pay, and free shuttle coa...          Sha Tin
# 10731  [HTML5, CSS, JavaScript, React.js, Bootstrap, ...  Central-Western
# 11195  [Attractive Salary Package depends on ability,...         Wan Chai
# 13721  [assist in the research project, ecruit partic...         Southern
# 17225  [Formulate cloud computing platform strategy, ...           Tai Po
# ...                                                  ...              ...
# 5309                                                  []           Others
# 5314   [Market leader in the industry, Regional offic...           Others
# 17519                   [Client side representative, , ]           Others
# 5330                                                  []           Others
# 9849                                                  []           Others
#
#                                               categories           post_time  \
# 10748  [Information Technology (IT), Application Spec... 2022-01-18 02:12:49
# 10731  [Information Technology (IT), Application Spec... 2022-01-17 09:46:43
# 11195  [Information Technology (IT), Hardware, Suppor... 2022-01-07 09:31:21
# 13721  [Admin & HR, Clerical / Admin Staff, HR Suppor... 2022-01-14 03:41:33
# 17225  [Engineering, Engineering Project Management, ... 2022-01-18 03:11:52
# ...                                                  ...                 ...
# 5309   [Sales, CS & Business Devpt, Retail Sales, Who... 2022-01-16 13:30:37
# 5314   [Transportation & Logistics, Supply Chain, Sal... 2022-01-13 08:38:54
# 17519  [Engineering, Electrical / Electronics, Engine... 2022-01-18 02:46:26
# 5330   [Sales, CS & Business Devpt, Retail Sales, Who... 2022-01-13 02:08:35
# 9849   [Admin & HR, Administration / Operation Manage... 2022-01-13 08:11:12
#
#        ...                                   responsibilities  \
# 10748  ...  [software, implementation, design, communicati...
# 10731  ...  [software, implementation, design, communicati...
# 11195  ...  [administration, installation, cost, software,...
# 13721  ...  [communication, review, administrative tasks, ...
# 17225  ...  [commissioning, software, information security...
# ...    ...                                                ...
# 5309   ...                                                 []
# 5314   ...  [management, work under pressure, sales target...
# 17519  ...  [commissioning, quality, monitor, testing, sit...
# 5330   ...                                         [facebook]
# 9849   ...                                                 []
#
#                                             requirements  \
# 10748  {'degrees': ['degree'], 'majors': ['computer e...
# 10731  {'degrees': ['degree'], 'majors': ['computer e...
# 11195  {'degrees': [], 'majors': [], 'languages': ['e...
# 13721  {'degrees': [], 'majors': [], 'languages': ['c...
# 17225  {'degrees': ['bachelor degree holder', 'master...
# ...                                                  ...
# 5309   {'degrees': [], 'majors': [], 'languages': [],...
# 5314   {'degrees': [], 'majors': [], 'languages': [],...
# 17519  {'degrees': ['certificate', 'diploma or above'...
# 5330   {'degrees': [], 'majors': [], 'languages': [],...
# 9849   {'degrees': [], 'majors': [], 'languages': [],...
#
#                                      experience_required  \
# 10748  {'duration': ['5 years'], 'field': ['product d...
# 10731  {'duration': ['5 years'], 'field': ['product d...
# 11195                      {'duration': [], 'field': []}
# 13721                      {'duration': [], 'field': []}
# 17225  {'duration': ['at least 2 years', 'at least 5 ...
# ...                                                  ...
# 5309                       {'duration': [], 'field': []}
# 5314                       {'duration': [], 'field': []}
# 17519  {'duration': ['at least 3 years'], 'field': ['...
# 5330                       {'duration': [], 'field': []}
# 9849                       {'duration': [], 'field': []}
#
#                              tier-1_type                       tier-2_type  \
# 10748             information-technology   application-specialist-software
# 10731             information-technology   application-specialist-software
# 11195             information-technology                          hardware
# 13721  sciences-lab-research-development              research-development
# 17225                        engineering    engineering-project-management
# ...                                  ...                               ...
# 5309             sales-cs-business-devpt                         wholesale
# 5314             sales-cs-business-devpt                         wholesale
# 17519                        engineering  telecommunication-wireless-radio
# 5330             sales-cs-business-devpt                         wholesale
# 9849                        public-civil                other-public-civil
#
#       hard_skill_score soft_skill_score language_score  location_score  \
# 10748            1.000              0.0       0.857143        1.000000
# 10731            1.000              0.0       0.857143        0.822337
# 11195            1.000              0.0       0.800000        0.816406
# 13721            0.875              0.0       1.000000        0.661062
# 17225            0.875              0.0       0.857143        0.930763
# ...                ...              ...            ...             ...
# 5309             0.000              0.0       0.000000        0.000000
# 5314             0.000              0.0       0.000000        0.000000
# 17519            0.000              0.0       0.000000        0.000000
# 5330             0.000              0.0       0.000000        0.000000
# 9849             0.000              0.0       0.000000        0.000000
#
#        integrated_score
# 10748          1.678571
# 10731          1.634156
# 11195          1.604102
# 13721          1.540265
# 17225          1.536262
# ...                 ...
# 5309           0.000000
# 5314           0.000000
# 17519          0.000000
# 5330           0.000000
# 9849           0.000000
#
# [19699 rows x 23 columns]
