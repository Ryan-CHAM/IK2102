# %%
'''
This script gives possible paths from present occupation to target occupation.
Input:
    1. Database of jobs
    2. Present occupation
    3. Target occupation
Output: Paths
'''
# Out:
# '\nThis script gives possible paths from present occupation to target occupation.\nInput:\n    1. Database of jobs\n    2. Present occupation\n    3. Target occupation\nOutput: Paths\n'

# %%
import pandas as pd
import networkx as nx

# %%
# TODO: modify input instead of demo input below
source = 'software-development'
target = 'photography-video'

# %%
# TODO: insert real data instead of demo data below
jobs = pd.read_json("support/data.json")

# %%
# read data
type_vocab, skill_vocab, pair_vocab = {}, {}, {}
for i in range(len(jobs)):
    t = jobs['tier-2_type'][i]
    type_vocab[t] = type_vocab.get(t, 0) + 1
    for s in jobs['requirements'][i]['hard_skills']:
        skill_vocab[s] = skill_vocab.get(s, 0) + 1
        p = (s, t)
        pair_vocab[p] = pair_vocab.get(p, 0) + 1

# %%
# build occupation-skill graph
G1 = nx.Graph()
for t in type_vocab.keys(): G1.add_node(t)
for s in skill_vocab.keys(): G1.add_node(s)
for p in pair_vocab.keys(): G1.add_edge(p[0], p[1])

# %%
# calculate jaccard distance
jaccard_dict = {}
for t1 in type_vocab.keys():
    for t2 in type_vocab.keys():
        if not (t1, t2) in jaccard_dict and not (t2, t1) in jaccard_dict and t1 != t2:
            s1 = set(G1.neighbors(t1))
            s2 = set(G1.neighbors(t2))
            jaccard_dict[(t1, t2)] = 1 - len(s1 & s2) / len(s1 | s2)

# %%
# build job transition graph
G2 = nx.Graph()
for t in type_vocab.keys(): G2.add_node(t)
for j in jaccard_dict.items():
    if j[1] <= 0.6: G2.add_edge(j[0][0], j[0][1], weight=j[1])

# %%
# TODO: take output here
print("Shortest path: %s" % nx.shortest_path(G2, source, target, 'weight'))
print("Length: %s" % nx.shortest_path_length(G2, source, target, 'weight'))
# Out:
# Shortest path: ['software-development', 'ui-ux-designer', 'creative-design', 'photography-video']
# Length: 1.7320430295658946

# %%
pair_vocab
# Out:
# {('project management', 'building-construction-qs'): 10,
#  ('autocad', 'building-construction-qs'): 22,
#  ('computer skills', 'building-construction-qs'): 6,
#  ('microsoft office', 'building-construction-qs'): 6,
#  ('make', 'building-construction-qs'): 3,
#  ('problem solving skills', 'building-construction-qs'): 11,
#  ('sketchup', 'building-construction-qs'): 2,
#  ('photoshop', 'building-construction-qs'): 4,
#  ('revit', 'building-construction-qs'): 4,
#  ('bim', 'building-construction-qs'): 5,
#  ('hkis', 'building-construction-qs'): 3,
#  ('pc applications', 'building-construction-qs'): 1,
#  ('certificate of registration of electrical worker',
#   'building-construction-qs'): 1,
#  ('maintenance', 'building-construction-qs'): 14,
#  ('green card', 'building-construction-qs'): 3,
#  ('no', 'building-construction-qs'): 2,
#  ('word', 'building-construction-qs'): 7,
#  ('analysis', 'building-construction-qs'): 3,
#  ('documentation', 'building-construction-qs'): 3,
#  ('rapid', 'building-construction-qs'): 1,
#  ('microsoft excel', 'building-construction-qs'): 9,
#  ('max', 'building-construction-qs'): 1,
#  ('microsoft office suite', 'building-construction-qs'): 8,
#  ('microsoft word', 'building-construction-qs'): 5,
#  ('basic', 'building-construction-qs'): 2,
#  ('c', 'building-construction-qs'): 1,
#  ('microsoft project', 'building-construction-qs'): 1,
#  ('safe', 'building-construction-qs'): 3,
#  ('dynamic', 'building-construction-qs'): 2,
#  ('acumen', 'building-construction-qs'): 1,
#  ('red', 'building-construction-qs'): 1,
#  ('agile', 'building-construction-qs'): 1,
#  ('fun', 'building-construction-qs'): 1,
#  ('pc', 'building-construction-qs'): 4,
#  ('tcp', 'building-construction-qs'): 3,
#  ('chinese word processing', 'building-construction-qs'): 1,
#  ('sizable companies', 'building-construction-qs'): 1,
#  ('restful api', 'building-construction-qs'): 1,
#  ('java', 'building-construction-qs'): 1,
#  ('plus', 'building-construction-qs'): 3,
#  ('sql', 'building-construction-qs'): 1,
#  ('javascript', 'building-construction-qs'): 1,
#  ('database programming', 'building-construction-qs'): 1,
#  ('programming', 'building-construction-qs'): 1,
#  ('python', 'building-construction-qs'): 1,
#  ('professional qualifications', 'building-construction-qs'): 2,
#  ('sap2000', 'building-construction-qs'): 1,
#  ('code', 'building-construction-qs'): 1,
#  ('cad', 'building-construction-qs'): 2,
#  ('material handling system', 'building-construction-qs'): 1,
#  ('deployment', 'building-construction-qs'): 1,
#  ('pe', 'building-construction-qs'): 1,
#  ('hkie', 'building-construction-qs'): 7,
#  ('words', 'building-construction-qs'): 2,
#  ('cctv', 'building-construction-qs'): 1,
#  ('chinese and english word processing', 'building-construction-qs'): 1,
#  ('typing', 'building-construction-qs'): 1,
#  ('powerpoint', 'building-construction-qs'): 1,
#  ('hkicm', 'building-construction-qs'): 2,
#  ('ciob', 'building-construction-qs'): 3,
#  ('sketch up', 'building-construction-qs'): 1,
#  ('focus', 'building-construction-qs'): 1,
#  ('illustrator', 'building-construction-qs'): 1,
#  ('hong kong construction and building related legislations',
#   'building-construction-qs'): 1,
#  ('fire services system', 'building-construction-qs'): 1,
#  ('building and a&a works', 'building-construction-qs'): 1,
#  ('plumbing and drainage system', 'building-construction-qs'): 1,
#  ('submission process', 'building-construction-qs'): 1,
#  ('knowledge of hvac', 'building-construction-qs'): 1,
#  ('electrical and lighting system', 'building-construction-qs'): 1,
#  ('elv system', 'building-construction-qs'): 1,
#  ('rics', 'building-construction-qs'): 1,
#  ('av system', 'building-construction-qs'): 1,
#  ('construction site safety requirements', 'building-construction-qs'): 1,
#  ('php', 'building-construction-qs'): 1,
#  ('mhkicm', 'building-construction-qs'): 1,
#  ('maib', 'building-construction-qs'): 1,
#  ('mciob', 'building-construction-qs'): 2,
#  ('mhkie', 'building-construction-qs'): 3,
#  ('facilities management', 'building-construction-qs'): 3,
#  ('processing', 'building-construction-qs'): 1,
#  ('power point', 'building-construction-qs'): 1,
#  ('whatsapp', 'building-construction-qs'): 1,
#  ('hong kong construction and building related legislations',
#   'architectural-services'): 1,
#  ('facilities management', 'architectural-services'): 2,
#  ('bim', 'architectural-services'): 7,
#  ('documentation', 'architectural-services'): 5,
#  ('microsoft office suite', 'architectural-services'): 14,
#  ('submission process', 'architectural-services'): 1,
#  ('autocad', 'architectural-services'): 49,
#  ('rhino', 'architectural-services'): 7,
#  ('adobe', 'architectural-services'): 5,
#  ('sketchup', 'architectural-services'): 23,
#  ('project management', 'architectural-services'): 24,
#  ('sketch up', 'architectural-services'): 1,
#  ('focus', 'architectural-services'): 3,
#  ('building information modelling', 'architectural-services'): 1,
#  ('microsoft excel', 'architectural-services'): 7,
#  ('no', 'architectural-services'): 6,
#  ('hkie', 'architectural-services'): 1,
#  ('maintenance', 'architectural-services'): 3,
#  ('hkis', 'architectural-services'): 3,
#  ('hksi', 'architectural-services'): 2,
#  ('problem solving skills', 'architectural-services'): 8,
#  ('hope', 'architectural-services'): 1,
#  ('whatsapp', 'architectural-services'): 2,
#  ('presentations', 'architectural-services'): 5,
#  ('make', 'architectural-services'): 2,
#  ('photoshop', 'architectural-services'): 24,
#  ('revit', 'architectural-services'): 11,
#  ('management reports', 'architectural-services'): 1,
#  ('goal', 'architectural-services'): 2,
#  ('deployment', 'architectural-services'): 1,
#  ('analytical skills', 'architectural-services'): 5,
#  ('graphics', 'architectural-services'): 1,
#  ('microsoft project', 'architectural-services'): 2,
#  ('adobe photoshop', 'architectural-services'): 2,
#  ('adobe illustrator', 'architectural-services'): 1,
#  ('integration', 'architectural-services'): 1,
#  ('plus', 'architectural-services'): 7,
#  ('dynamic', 'architectural-services'): 2,
#  ('ai', 'architectural-services'): 3,
#  ('max', 'architectural-services'): 2,
#  ('safe', 'architectural-services'): 2,
#  ('microsoft office', 'architectural-services'): 3,
#  ('basic', 'architectural-services'): 1,
#  ('bim modelling', 'architectural-services'): 1,
#  ('3d modelling', 'architectural-services'): 2,
#  ('word', 'architectural-services'): 3,
#  ('powerpoint', 'architectural-services'): 4,
#  ('pc', 'architectural-services'): 2,
#  ('3ds max', 'architectural-services'): 2,
#  ('microsoft word', 'architectural-services'): 4,
#  ('web', 'architectural-services'): 1,
#  ('adobe indesign', 'architectural-services'): 1,
#  ('illustrator', 'architectural-services'): 3,
#  ('after effects', 'architectural-services'): 1,
#  ('in-design', 'architectural-services'): 3,
#  ('go', 'architectural-services'): 1,
#  ('simple', 'architectural-services'): 1,
#  ('code', 'architectural-services'): 1,
#  ('green card', 'architectural-services'): 1,
#  ('mhkie', 'architectural-services'): 1,
#  ('mciob', 'architectural-services'): 1,
#  ('problem solving capabilities', 'architectural-services'): 1,
#  ('chinese word processing', 'architectural-services'): 1,
#  ('vendor', 'architectural-services'): 1,
#  ('processing', 'architectural-services'): 1,
#  ('computer skills', 'architectural-services'): 2,
#  ('ap', 'architectural-services'): 2,
#  ('pc knowledge', 'architectural-services'): 1,
#  ('analysis', 'architectural-services'): 1,
#  ('programming', 'architectural-services'): 1,
#  ('c', 'architectural-services'): 1,
#  ('wan', 'architectural-services'): 1,
#  ('cad', 'architectural-services'): 3,
#  ('plc', 'architectural-services'): 1,
#  ('switch', 'architectural-services'): 1,
#  ('tcp', 'architectural-services'): 1,
#  ('scheme', 'architectural-services'): 1,
#  ('acrobat', 'architectural-services'): 1,
#  ('pc applications', 'architectural-services'): 1,
#  ('typing', 'architectural-services'): 1,
#  ('bim', 'civil-structural'): 11,
#  ('plus', 'civil-structural'): 7,
#  ('revit', 'civil-structural'): 5,
#  ('presentation skill', 'civil-structural'): 1,
#  ('analysis', 'civil-structural'): 6,
#  ('sap2000', 'civil-structural'): 3,
#  ('autocad', 'civil-structural'): 20,
#  ('linux', 'civil-structural'): 1,
#  ('restful api', 'civil-structural'): 1,
#  ('web', 'civil-structural'): 3,
#  ('devops', 'civil-structural'): 2,
#  ('jquery', 'civil-structural'): 2,
#  ('project management', 'civil-structural'): 12,
#  ('mobile', 'civil-structural'): 2,
#  ('javascript', 'civil-structural'): 2,
#  ('programming', 'civil-structural'): 4,
#  ('ajax', 'civil-structural'): 1,
#  ('server', 'civil-structural'): 1,
#  ('ms sql', 'civil-structural'): 2,
#  ('c#', 'civil-structural'): 3,
#  ('clean', 'civil-structural'): 3,
#  ('java', 'civil-structural'): 1,
#  ('react', 'civil-structural'): 1,
#  ('angular', 'civil-structural'): 1,
#  ('code', 'civil-structural'): 4,
#  ('web services', 'civil-structural'): 1,
#  ('android', 'civil-structural'): 1,
#  ('sql', 'civil-structural'): 2,
#  ('problem solving skills', 'civil-structural'): 7,
#  ('tcp', 'civil-structural'): 5,
#  ('no', 'civil-structural'): 4,
#  ('the hong kong institution of engineers', 'civil-structural'): 1,
#  ('analytical skills', 'civil-structural'): 3,
#  ('hkie', 'civil-structural'): 6,
#  ('microsoft project', 'civil-structural'): 3,
#  ('chinese word processing', 'civil-structural'): 3,
#  ('microsoft office', 'civil-structural'): 7,
#  ('green card', 'civil-structural'): 5,
#  ('mhkie', 'civil-structural'): 6,
#  ('microsoft office suite', 'civil-structural'): 12,
#  ('cad', 'civil-structural'): 3,
#  ('microsoft excel', 'civil-structural'): 9,
#  ('word', 'civil-structural'): 4,
#  ('words', 'civil-structural'): 1,
#  ('sketchup', 'civil-structural'): 1,
#  ('photoshop', 'civil-structural'): 2,
#  ('scheme', 'civil-structural'): 4,
#  ('dynamic', 'civil-structural'): 3,
#  ('fun', 'civil-structural'): 1,
#  ('php', 'civil-structural'): 1,
#  ('powerpoint', 'civil-structural'): 4,
#  ('microsoft word', 'civil-structural'): 2,
#  ('maintenance', 'civil-structural'): 4,
#  ('pipelines', 'civil-structural'): 1,
#  ('basic', 'civil-structural'): 2,
#  ('mathcad', 'civil-structural'): 1,
#  ('construction workers registration card', 'civil-structural'): 1,
#  ('etabs', 'civil-structural'): 1,
#  ('sads', 'civil-structural'): 1,
#  ('safe', 'civil-structural'): 1,
#  ('make', 'civil-structural'): 3,
#  ('wan', 'civil-structural'): 1,
#  ('documentation', 'civil-structural'): 1,
#  ('outlook', 'civil-structural'): 2,
#  ('adobe indesign', 'civil-structural'): 1,
#  ('illustrator', 'civil-structural'): 1,
#  ('multimedia', 'civil-structural'): 1,
#  ('dreamweaver', 'civil-structural'): 1,
#  ('analytics tools', 'civil-structural'): 1,
#  ('bi', 'civil-structural'): 1,
#  ('system implementation', 'civil-structural'): 1,
#  ('oracle', 'civil-structural'): 1,
#  ('ap', 'civil-structural'): 1,
#  ('container', 'civil-structural'): 1,
#  ('html', 'civil-structural'): 1,
#  ('rhino', 'civil-structural'): 1,
#  ('bim modelling', 'civil-structural'): 1,
#  ('dynamo', 'civil-structural'): 1,
#  ('pc knowledge', 'civil-structural'): 1,
#  ('id', 'civil-structural'): 1,
#  ('deployment', 'civil-structural'): 1,
#  ('focus', 'civil-structural'): 1,
#  ('microsoft excel', 'other-building-construction'): 18,
#  ('chinese word processing', 'other-building-construction'): 9,
#  ('word', 'other-building-construction'): 10,
#  ('microsoft office suite', 'other-building-construction'): 19,
#  ('maintenance', 'other-building-construction'): 8,
#  ('ai', 'other-building-construction'): 2,
#  ('sketchup', 'other-building-construction'): 3,
#  ('photoshop', 'other-building-construction'): 6,
#  ('max', 'other-building-construction'): 1,
#  ('autocad', 'other-building-construction'): 16,
#  ('whatsapp', 'other-building-construction'): 3,
#  ('problem solving skills', 'other-building-construction'): 6,
#  ('project management', 'other-building-construction'): 6,
#  ('computer skills', 'other-building-construction'): 8,
#  ('no', 'other-building-construction'): 2,
#  ('first aid certificate', 'other-building-construction'): 1,
#  ('ems', 'other-building-construction'): 1,
#  ('basic', 'other-building-construction'): 3,
#  ('pc knowledge', 'other-building-construction'): 2,
#  ('revit', 'other-building-construction'): 6,
#  ('codes and regulations', 'other-building-construction'): 1,
#  ('powerpoint', 'other-building-construction'): 5,
#  ('plus', 'other-building-construction'): 2,
#  ('hvac', 'other-building-construction'): 1,
#  ('bms', 'other-building-construction'): 1,
#  ('code', 'other-building-construction'): 3,
#  ('red', 'other-building-construction'): 1,
#  ('agile', 'other-building-construction'): 1,
#  ('fun', 'other-building-construction'): 1,
#  ('tcp', 'other-building-construction'): 1,
#  ('bim', 'other-building-construction'): 5,
#  ('hkis', 'other-building-construction'): 1,
#  ('facilities management', 'other-building-construction'): 2,
#  ('c', 'other-building-construction'): 1,
#  ('certificate of registration of electrical worker',
#   'other-building-construction'): 1,
#  ('words', 'other-building-construction'): 2,
#  ('microsoft office', 'other-building-construction'): 2,
#  ('graphics', 'other-building-construction'): 1,
#  ('microsoft project', 'other-building-construction'): 2,
#  ('adobe photoshop', 'other-building-construction'): 1,
#  ('adobe illustrator', 'other-building-construction'): 1,
#  ('green card', 'other-building-construction'): 3,
#  ('scheme', 'other-building-construction'): 1,
#  ('microsoft word', 'other-building-construction'): 4,
#  ('safe', 'other-building-construction'): 1,
#  ('pc applications', 'other-building-construction'): 1,
#  ('typing', 'other-building-construction'): 3,
#  ('mhkie', 'other-building-construction'): 2,
#  ('power point', 'other-building-construction'): 1,
#  ('pc operations', 'other-building-construction'): 1,
#  ('documentation', 'other-building-construction'): 1,
#  ('hkie', 'other-building-construction'): 1,
#  ('pc', 'other-building-construction'): 1,
#  ('3ds max', 'other-building-construction'): 1,
#  ('rhino', 'other-building-construction'): 1,
#  ('realtime landscaping', 'other-building-construction'): 1,
#  ('revit architecture', 'other-building-construction'): 1,
#  ('acumen', 'other-building-construction'): 1,
#  ('professional qualifications', 'other-building-construction'): 1,
#  ('cpa', 'audit'): 27,
#  ('pc knowledge', 'audit'): 4,
#  ('microsoft office suite', 'audit'): 13,
#  ('microsoft excel', 'audit'): 22,
#  ('companies ordinance', 'audit'): 2,
#  ('microsoft word', 'audit'): 13,
#  ('accounting softwares', 'audit'): 7,
#  ('acca', 'audit'): 19,
#  ('chinese word processing', 'audit'): 6,
#  ('pc', 'audit'): 2,
#  ('hkicpa', 'audit'): 28,
#  ('no', 'audit'): 11,
#  ('small', 'audit'): 3,
#  ('scheme', 'audit'): 8,
#  ('problem solving skills', 'audit'): 6,
#  ('word', 'audit'): 7,
#  ('accounting systems', 'audit'): 2,
#  ('computer skills', 'audit'): 3,
#  ('analysis', 'audit'): 1,
#  ('processing', 'audit'): 2,
#  ('basic', 'audit'): 3,
#  ('myob', 'audit'): 3,
#  ('powerpoint', 'audit'): 1,
#  ('c', 'audit'): 2,
#  ('wan', 'audit'): 3,
#  ('hong kong institute of certified public accountants', 'audit'): 1,
#  ('peachtree', 'audit'): 1,
#  ('xero', 'audit'): 1,
#  ('writing skills', 'audit'): 1,
#  ('prc accounting', 'audit'): 2,
#  ('financial analysis', 'audit'): 1,
#  ('management reports', 'audit'): 1,
#  ('oracle', 'audit'): 1,
#  ('microsoft office', 'audit'): 2,
#  ('hkfrs', 'audit'): 1,
#  ('system implementation', 'audit'): 1,
#  ('erp', 'audit'): 1,
#  ('data analytics', 'audit'): 1,
#  ('plus', 'audit'): 3,
#  ('programming', 'audit'): 1,
#  ('project management', 'audit'): 1,
#  ('analytical skills', 'audit'): 3,
#  ('simple', 'audit'): 1,
#  ('goal', 'audit'): 1,
#  ('professional qualifications', 'audit'): 1,
#  ('dynamic', 'audit'): 1,
#  ('r', 'audit'): 1,
#  ('microsoft excel', 'chief-accountant'): 33,
#  ('microsoft office suite', 'chief-accountant'): 23,
#  ('word', 'chief-accountant'): 26,
#  ('powerpoint', 'chief-accountant'): 12,
#  ('erp systems', 'chief-accountant'): 14,
#  ('gm', 'chief-accountant'): 9,
#  ('r', 'chief-accountant'): 4,
#  ('prc manufacturing', 'chief-accountant'): 4,
#  ('plus', 'chief-accountant'): 25,
#  ('accounting softwares', 'chief-accountant'): 2,
#  ('analysis', 'chief-accountant'): 11,
#  ('management reports', 'chief-accountant'): 8,
#  ('oracle', 'chief-accountant'): 5,
#  ('cpa', 'chief-accountant'): 24,
#  ('acca', 'chief-accountant'): 21,
#  ('presentations', 'chief-accountant'): 2,
#  ('hkicpa', 'chief-accountant'): 25,
#  ('acumen', 'chief-accountant'): 12,
#  ('microsoft word', 'chief-accountant'): 4,
#  ('problem solving skills', 'chief-accountant'): 12,
#  ('dynamic', 'chief-accountant'): 13,
#  ('internal control', 'chief-accountant'): 4,
#  ('typewriting', 'chief-accountant'): 1,
#  ('chinese word processing', 'chief-accountant'): 6,
#  ('analytical skills', 'chief-accountant'): 9,
#  ('oracle system', 'chief-accountant'): 3,
#  ('pc knowledge', 'chief-accountant'): 6,
#  ('professional qualifications', 'chief-accountant'): 6,
#  ('project management', 'chief-accountant'): 2,
#  ('microsoft office', 'chief-accountant'): 3,
#  ('e-commerce', 'chief-accountant'): 2,
#  ('bi', 'chief-accountant'): 2,
#  ('words', 'chief-accountant'): 4,
#  ('sizable companies', 'chief-accountant'): 4,
#  ('accounting systems', 'chief-accountant'): 5,
#  ('fmcg industry', 'chief-accountant'): 2,
#  ('cfa', 'chief-accountant'): 2,
#  ('sap', 'chief-accountant'): 6,
#  ('ifrs', 'chief-accountant'): 3,
#  ('myob', 'chief-accountant'): 1,
#  ('inform', 'chief-accountant'): 1,
#  ('reason', 'chief-accountant'): 1,
#  ('mpf regulations', 'chief-accountant'): 1,
#  ('computer skills', 'chief-accountant'): 1,
#  ('xero', 'chief-accountant'): 1,
#  ('outlook', 'chief-accountant'): 3,
#  ('hkfrs', 'chief-accountant'): 1,
#  ('erp', 'chief-accountant'): 1,
#  ('financial analysis', 'chief-accountant'): 3,
#  ('prc accounting', 'chief-accountant'): 3,
#  ('system implementation', 'chief-accountant'): 1,
#  ('spreadsheet', 'chief-accountant'): 2,
#  ('ap', 'chief-accountant'): 1,
#  ('ar', 'chief-accountant'): 1,
#  ('agile', 'chief-accountant'): 1,
#  ('flex', 'chief-accountant'): 1,
#  ('processing', 'chief-accountant'): 1,
#  ('basic', 'chief-accountant'): 1,
#  ('lean', 'chief-accountant'): 1,
#  ('microsoft excel', 'treasurer'): 24,
#  ('plus', 'treasurer'): 9,
#  ('microsoft office', 'treasurer'): 2,
#  ('word', 'treasurer'): 14,
#  ('powerpoint', 'treasurer'): 8,
#  ('system implementation', 'treasurer'): 2,
#  ('oracle', 'treasurer'): 5,
#  ('ap', 'treasurer'): 3,
#  ('ar', 'treasurer'): 2,
#  ('lcc', 'treasurer'): 4,
#  ('microsoft word', 'treasurer'): 7,
#  ('problem solving skills', 'treasurer'): 8,
#  ('pc', 'treasurer'): 2,
#  ('acca', 'treasurer'): 5,
#  ('vba', 'treasurer'): 1,
#  ('analytical skills', 'treasurer'): 4,
#  ('hkicpa', 'treasurer'): 6,
#  ('exchange', 'treasurer'): 2,
#  ('cpa', 'treasurer'): 8,
#  ('xero', 'treasurer'): 1,
#  ('microsoft office suite', 'treasurer'): 10,
#  ('flex system', 'treasurer'): 3,
#  ('chinese word processing', 'treasurer'): 4,
#  ('macro', 'treasurer'): 7,
#  ('mobile', 'treasurer'): 7,
#  ('presentation skill', 'treasurer'): 1,
#  ('dynamic', 'treasurer'): 4,
#  ('documentation', 'treasurer'): 2,
#  ('sizable companies', 'treasurer'): 2,
#  ('internal control', 'treasurer'): 8,
#  ('analysis', 'treasurer'): 2,
#  ('pe', 'treasurer'): 1,
#  ('sap', 'treasurer'): 8,
#  ('professional qualifications', 'treasurer'): 1,
#  ('accounting softwares', 'treasurer'): 1,
#  ('accounting systems', 'treasurer'): 2,
#  ('accpac', 'treasurer'): 1,
#  ('processing', 'treasurer'): 3,
#  ('code', 'treasurer'): 2,
#  ('outlook', 'treasurer'): 1,
#  ('swift', 'treasurer'): 1,
#  ('private equity', 'treasurer'): 2,
#  ('acumen', 'treasurer'): 6,
#  ('companies ordinance', 'treasurer'): 5,
#  ('computer skills', 'treasurer'): 6,
#  ('airlines', 'treasurer'): 2,
#  ('microsoft powerpoint', 'treasurer'): 1,
#  ('no', 'treasurer'): 2,
#  ('html', 'treasurer'): 2,
#  ('make', 'treasurer'): 2,
#  ('c', 'treasurer'): 1,
#  ('crypto', 'treasurer'): 2,
#  ('investment products', 'treasurer'): 2,
#  ('go', 'treasurer'): 1,
#  ('ladder', 'treasurer'): 1,
#  ('business management', 'treasurer'): 1,
#  ('maintenance', 'treasurer'): 1,
#  ('focus', 'treasurer'): 1,
#  ('gap', 'treasurer'): 1,
#  ('spreadsheet', 'treasurer'): 2,
#  ('word processing', 'treasurer'): 1,
#  ('fms', 'treasurer'): 1,
#  ('cfa', 'treasurer'): 2,
#  ('project management', 'treasurer'): 3,
#  ('fmcg industry', 'treasurer'): 1,
#  ('fun', 'treasurer'): 1,
#  ('netsuite system', 'treasurer'): 1,
#  ('safe', 'treasurer'): 1,
#  ('flex', 'treasurer'): 1,
#  ('microsoft excel', 'other-accounting'): 39,
#  ('basic', 'other-accounting'): 6,
#  ('microsoft office', 'other-accounting'): 9,
#  ('words', 'other-accounting'): 2,
#  ('lcc', 'other-accounting'): 9,
#  ('presentations', 'other-accounting'): 2,
#  ('sap', 'other-accounting'): 5,
#  ('microsoft office suite', 'other-accounting'): 25,
#  ('oracle system', 'other-accounting'): 2,
#  ('billing system', 'other-accounting'): 2,
#  ('accounting systems', 'other-accounting'): 5,
#  ('chinese word processing', 'other-accounting'): 9,
#  ('peachtree', 'other-accounting'): 5,
#  ('xero', 'other-accounting'): 1,
#  ('erp systems', 'other-accounting'): 2,
#  ('vba', 'other-accounting'): 1,
#  ('e-commerce', 'other-accounting'): 1,
#  ('account opening', 'other-accounting'): 2,
#  ('marco', 'other-accounting'): 1,
#  ('computer skills', 'other-accounting'): 7,
#  ('word', 'other-accounting'): 16,
#  ('powerpoint', 'other-accounting'): 3,
#  ('gm', 'other-accounting'): 1,
#  ('r', 'other-accounting'): 1,
#  ('wan', 'other-accounting'): 1,
#  ('ecc', 'other-accounting'): 1,
#  ('microsoft word', 'other-accounting'): 7,
#  ('dynamic', 'other-accounting'): 1,
#  ('erp', 'other-accounting'): 2,
#  ('typing', 'other-accounting'): 2,
#  ('writing skills', 'other-accounting'): 2,
#  ('plus', 'other-accounting'): 6,
#  ('vendor', 'other-accounting'): 2,
#  ('documentation', 'other-accounting'): 1,
#  ('oracle', 'other-accounting'): 3,
#  ('outlook', 'other-accounting'): 1,
#  ('acca', 'other-accounting'): 10,
#  ('hkicpa', 'other-accounting'): 14,
#  ('ap', 'other-accounting'): 1,
#  ('ar', 'other-accounting'): 1,
#  ('accounting softwares', 'other-accounting'): 3,
#  ('flex system', 'other-accounting'): 3,
#  ('no', 'other-accounting'): 4,
#  ('oracle erp', 'other-accounting'): 1,
#  ('analytical skills', 'other-accounting'): 2,
#  ('problem solving skills', 'other-accounting'): 6,
#  ('analysis', 'other-accounting'): 1,
#  ('cpa', 'other-accounting'): 6,
#  ('sizable companies', 'other-accounting'): 1,
#  ('acumen', 'other-accounting'): 1,
#  ('crs', 'other-accounting'): 2,
#  ('project management', 'other-accounting'): 1,
#  ('fatca', 'other-accounting'): 2,
#  ('exchange', 'other-accounting'): 3,
#  ('flex accounting', 'other-accounting'): 5,
#  ('small', 'other-accounting'): 1,
#  ('databases', 'other-accounting'): 1,
#  ('go', 'other-accounting'): 1,
#  ('business intelligence', 'other-accounting'): 1,
#  ('financial analysis', 'other-accounting'): 1,
#  ('management reports', 'other-accounting'): 1,
#  ('data analytics', 'other-accounting'): 1,
#  ('microsoft applications', 'other-accounting'): 1,
#  ('myob', 'other-accounting'): 2,
#  ('chinese input', 'other-accounting'): 1,
#  ('aml', 'other-accounting'): 1,
#  ('cdd', 'other-accounting'): 1,
#  ('customer due diligence', 'other-accounting'): 1,
#  ('anti-money laundering', 'other-accounting'): 1,
#  ('kyc', 'other-accounting'): 1,
#  ('pc knowledge', 'other-accounting'): 1,
#  ('swift', 'other-accounting'): 1,
#  ('professional qualifications', 'other-accounting'): 1,
#  ('c', 'other-accounting'): 2,
#  ('pc', 'other-accounting'): 2,
#  ('quickbooks', 'other-accounting'): 1,
#  ('chinese and english word processing', 'other-accounting'): 1,
#  ('business management', 'other-accounting'): 1,
#  ('pivot table', 'other-accounting'): 1,
#  ('blockchain', 'other-accounting'): 1,
#  ('crypto', 'other-accounting'): 1,
#  ('crypto currency', 'other-accounting'): 1,
#  ('chinese word processing', 'accounting-clerk-supervisor'): 18,
#  ('data management', 'accounting-clerk-supervisor'): 2,
#  ('maintenance', 'accounting-clerk-supervisor'): 2,
#  ('accounting softwares', 'accounting-clerk-supervisor'): 10,
#  ('focus', 'accounting-clerk-supervisor'): 2,
#  ('microsoft office suite', 'accounting-clerk-supervisor'): 40,
#  ('microsoft excel', 'accounting-clerk-supervisor'): 62,
#  ('microsoft word', 'accounting-clerk-supervisor'): 19,
#  ('erp', 'accounting-clerk-supervisor'): 4,
#  ('erp systems', 'accounting-clerk-supervisor'): 5,
#  ('peachtree', 'accounting-clerk-supervisor'): 7,
#  ('pc knowledge', 'accounting-clerk-supervisor'): 3,
#  ('chinese wp', 'accounting-clerk-supervisor'): 2,
#  ('microsoft office', 'accounting-clerk-supervisor'): 5,
#  ('problem solving skills', 'accounting-clerk-supervisor'): 4,
#  ('word', 'accounting-clerk-supervisor'): 29,
#  ('ap', 'accounting-clerk-supervisor'): 6,
#  ('ar', 'accounting-clerk-supervisor'): 6,
#  ('lcc', 'accounting-clerk-supervisor'): 11,
#  ('typing', 'accounting-clerk-supervisor'): 4,
#  ('pc', 'accounting-clerk-supervisor'): 2,
#  ('vendor', 'accounting-clerk-supervisor'): 2,
#  ('prc manufacturing', 'accounting-clerk-supervisor'): 1,
#  ('plus', 'accounting-clerk-supervisor'): 2,
#  ('outlook', 'accounting-clerk-supervisor'): 3,
#  ('spreadsheet', 'accounting-clerk-supervisor'): 2,
#  ('myob', 'accounting-clerk-supervisor'): 7,
#  ('accounting systems', 'accounting-clerk-supervisor'): 7,
#  ('basic', 'accounting-clerk-supervisor'): 5,
#  ('dynamic', 'accounting-clerk-supervisor'): 2,
#  ('powerpoint', 'accounting-clerk-supervisor'): 2,
#  ('scheme', 'accounting-clerk-supervisor'): 3,
#  ('no', 'accounting-clerk-supervisor'): 1,
#  ('c', 'accounting-clerk-supervisor'): 1,
#  ('computer skills', 'accounting-clerk-supervisor'): 6,
#  ('flex accounting', 'accounting-clerk-supervisor'): 2,
#  ('flex system', 'accounting-clerk-supervisor'): 4,
#  ('ms windows', 'accounting-clerk-supervisor'): 1,
#  ('xero', 'accounting-clerk-supervisor'): 2,
#  ('acumen', 'accounting-clerk-supervisor'): 1,
#  ('documentation', 'accounting-clerk-supervisor'): 1,
#  ('oracle', 'accounting-clerk-supervisor'): 1,
#  ('wan', 'accounting-clerk-supervisor'): 2,
#  ('databases', 'accounting-clerk-supervisor'): 1,
#  ('sap', 'accounting-clerk-supervisor'): 2,
#  ('words', 'accounting-clerk-supervisor'): 1,
#  ('acca', 'accounting-clerk-supervisor'): 2,
#  ('ecc', 'accounting-clerk-supervisor'): 1,
#  ('cpa', 'accounting-clerk-supervisor'): 1,
#  ('peachtree accounting system', 'accounting-clerk-supervisor'): 1,
#  ('presentation skill', 'accounting-clerk-supervisor'): 1,
#  ('prc accounting', 'accounting-clerk-supervisor'): 1,
#  ('oracle system', 'accounting-clerk-supervisor'): 1,
#  ('billing system', 'accounting-clerk-supervisor'): 1,
#  ('simple', 'accounting-clerk-supervisor'): 1,
#  ('analysis', 'accounting-clerk-supervisor'): 1,
#  ('make', 'accounting-clerk-supervisor'): 1,
#  ('analytical skills', 'accounting-clerk-supervisor'): 1,
#  ('microsoft excel', 'consulting'): 17,
#  ('acca', 'consulting'): 6,
#  ('chinese word processing', 'consulting'): 3,
#  ('word', 'consulting'): 7,
#  ('analytical skills', 'consulting'): 9,
#  ('cpa', 'consulting'): 13,
#  ('hkicpa', 'consulting'): 11,
#  ('microsoft office suite', 'consulting'): 12,
#  ('make', 'consulting'): 4,
#  ('microsoft word', 'consulting'): 1,
#  ('cfa', 'consulting'): 4,
#  ('problem solving skills', 'consulting'): 5,
#  ('accounting systems', 'consulting'): 2,
#  ('analysis', 'consulting'): 14,
#  ('word processing', 'consulting'): 1,
#  ('computer skills', 'consulting'): 1,
#  ('documentation', 'consulting'): 5,
#  ('vba', 'consulting'): 3,
#  ('plus', 'consulting'): 4,
#  ('professional qualifications', 'consulting'): 2,
#  ('programming', 'consulting'): 1,
#  ('python', 'consulting'): 4,
#  ('r', 'consulting'): 2,
#  ('frm', 'consulting'): 1,
#  ('rapid', 'consulting'): 2,
#  ('information system', 'consulting'): 1,
#  ('internal control', 'consulting'): 1,
#  ('fun', 'consulting'): 2,
#  ('erp', 'consulting'): 2,
#  ('focus', 'consulting'): 3,
#  ('ai', 'consulting'): 1,
#  ('data analytics', 'consulting'): 2,
#  ('vendor', 'consulting'): 2,
#  ('writing skills', 'consulting'): 3,
#  ('scheme', 'consulting'): 1,
#  ('microsoft office', 'consulting'): 3,
#  ('dynamic', 'consulting'): 3,
#  ('project management', 'consulting'): 6,
#  ('basic', 'consulting'): 3,
#  ('quickbooks', 'consulting'): 1,
#  ('peachtree', 'consulting'): 1,
#  ('myob', 'consulting'): 1,
#  ('certified public accountants', 'consulting'): 1,
#  ('ifrs', 'consulting'): 1,
#  ('acumen', 'consulting'): 2,
#  ('powerpoint', 'consulting'): 6,
#  ('cad', 'consulting'): 2,
#  ('adobe photoshop', 'consulting'): 2,
#  ('adobe illustrator', 'consulting'): 4,
#  ('solidworks', 'consulting'): 1,
#  ('in-design', 'consulting'): 1,
#  ('processing', 'consulting'): 2,
#  ('adobe acrobat', 'consulting'): 1,
#  ('photoshop', 'consulting'): 2,
#  ('simple', 'consulting'): 1,
#  ('presentations', 'consulting'): 3,
#  ('data mining', 'consulting'): 1,
#  ('macro', 'consulting'): 1,
#  ('bi', 'consulting'): 1,
#  ('sql', 'consulting'): 2,
#  ('oracle', 'consulting'): 3,
#  ('microsoft applications', 'consulting'): 3,
#  ('inform', 'consulting'): 4,
#  ('dcl', 'consulting'): 4,
#  ('pc knowledge', 'consulting'): 2,
#  ('red', 'consulting'): 1,
#  ('graphics', 'consulting'): 3,
#  ('acrobat', 'consulting'): 1,
#  ('adobe indesign', 'consulting'): 1,
#  ('translation', 'consulting'): 1,
#  ('go', 'consulting'): 2,
#  ('small', 'consulting'): 2,
#  ('azure', 'consulting'): 1,
#  ('maintenance', 'consulting'): 1,
#  ('databases', 'consulting'): 1,
#  ('supply planning', 'consulting'): 1,
#  ('vendor forecasting', 'consulting'): 1,
#  ('business management', 'consulting'): 1,
#  ('demand planning', 'consulting'): 1,
#  ('adobe creative suite', 'consulting'): 1,
#  ('3d software', 'consulting'): 1,
#  ('illustrator', 'consulting'): 1,
#  ('deployment', 'consulting'): 1,
#  ('integration', 'consulting'): 1,
#  ('no', 'consulting'): 1,
#  ('joy', 'consulting'): 1,
#  ('agile', 'consulting'): 1,
#  ('mad', 'consulting'): 1,
#  ('logical skills', 'consulting'): 1,
#  ('financial analysis', 'consulting'): 2,
#  ('fmcg industry', 'consulting'): 1,
#  ('pc', 'consulting'): 1,
#  ('microsoft excel', 'finance-accounting-manager'): 25,
#  ('internal control', 'finance-accounting-manager'): 6,
#  ('prc accounting', 'finance-accounting-manager'): 12,
#  ('hkicpa', 'finance-accounting-manager'): 30,
#  ('myob', 'finance-accounting-manager'): 3,
#  ('acumen', 'finance-accounting-manager'): 11,
#  ('financial analysis', 'finance-accounting-manager'): 4,
#  ('cpa', 'finance-accounting-manager'): 20,
#  ('plus', 'finance-accounting-manager'): 7,
#  ('microsoft office suite', 'finance-accounting-manager'): 15,
#  ('import and export', 'finance-accounting-manager'): 2,
#  ('acca', 'finance-accounting-manager'): 21,
#  ('problem solving skills', 'finance-accounting-manager'): 15,
#  ('analysis', 'finance-accounting-manager'): 7,
#  ('dynamic', 'finance-accounting-manager'): 3,
#  ('analytical skills', 'finance-accounting-manager'): 17,
#  ('erp systems', 'finance-accounting-manager'): 7,
#  ('vba', 'finance-accounting-manager'): 4,
#  ('e-commerce', 'finance-accounting-manager'): 2,
#  ('account opening', 'finance-accounting-manager'): 2,
#  ('marco', 'finance-accounting-manager'): 2,
#  ('computer skills', 'finance-accounting-manager'): 8,
#  ('bi', 'finance-accounting-manager'): 2,
#  ('agile', 'finance-accounting-manager'): 2,
#  ('powerpoint', 'finance-accounting-manager'): 11,
#  ('project management', 'finance-accounting-manager'): 3,
#  ('outlook', 'finance-accounting-manager'): 4,
#  ('alteryx', 'finance-accounting-manager'): 2,
#  ('chinese word processing', 'finance-accounting-manager'): 3,
#  ('word', 'finance-accounting-manager'): 9,
#  ('management reports', 'finance-accounting-manager'): 2,
#  ('accounting systems', 'finance-accounting-manager'): 8,
#  ('frr', 'finance-accounting-manager'): 3,
#  ('microsoft word', 'finance-accounting-manager'): 4,
#  ('pc knowledge', 'finance-accounting-manager'): 2,
#  ('small', 'finance-accounting-manager'): 5,
#  ('make', 'finance-accounting-manager'): 6,
#  ('business management', 'finance-accounting-manager'): 2,
#  ('exchange', 'finance-accounting-manager'): 3,
#  ('presentations', 'finance-accounting-manager'): 2,
#  ('no', 'finance-accounting-manager'): 3,
#  ('professional qualifications', 'finance-accounting-manager'): 4,
#  ('system implementation', 'finance-accounting-manager'): 3,
#  ('oracle', 'finance-accounting-manager'): 6,
#  ('word processing', 'finance-accounting-manager'): 2,
#  ('pc applications', 'finance-accounting-manager'): 2,
#  ('sehk', 'finance-accounting-manager'): 2,
#  ('fmcg industry', 'finance-accounting-manager'): 2,
#  ('sap', 'finance-accounting-manager'): 6,
#  ('microsoft office', 'finance-accounting-manager'): 2,
#  ('erp', 'finance-accounting-manager'): 2,
#  ('data management', 'finance-accounting-manager'): 1,
#  ('hksi', 'finance-accounting-manager'): 1,
#  ('programming', 'finance-accounting-manager'): 1,
#  ('frm', 'finance-accounting-manager'): 1,
#  ('flex accounting', 'finance-accounting-manager'): 2,
#  ('cfa', 'finance-accounting-manager'): 1,
#  ('crypto', 'finance-accounting-manager'): 1,
#  ('investment products', 'finance-accounting-manager'): 1,
#  ('go', 'finance-accounting-manager'): 1,
#  ('companies ordinance', 'finance-accounting-manager'): 1,
#  ('accounting softwares', 'finance-accounting-manager'): 2,
#  ('xero', 'finance-accounting-manager'): 1,
#  ('ap', 'finance-accounting-manager'): 1,
#  ('ar', 'finance-accounting-manager'): 1,
#  ('documentation', 'finance-accounting-manager'): 1,
#  ('hkfrs', 'finance-accounting-manager'): 2,
#  ('c', 'finance-accounting-manager'): 2,
#  ('r', 'finance-accounting-manager'): 1,
#  ('focus', 'finance-accounting-manager'): 1,
#  ('maintenance', 'finance-accounting-manager'): 1,
#  ('writing skills', 'finance-accounting-manager'): 1,
#  ('ifrs', 'finance-accounting-manager'): 1,
#  ('web', 'finance-accounting-manager'): 1,
#  ('io', 'finance-accounting-manager'): 1,
#  ('hong kong institute of certified public accountants',
#   'finance-accounting-manager'): 1,
#  ('association of chartered certified accountants',
#   'finance-accounting-manager'): 1,
#  ('problem solving skills', 'credit-control'): 14,
#  ('analysis', 'credit-control'): 9,
#  ('microsoft office suite', 'credit-control'): 26,
#  ('plus', 'credit-control'): 11,
#  ('microsoft excel', 'credit-control'): 45,
#  ('word', 'credit-control'): 13,
#  ('microsoft word', 'credit-control'): 14,
#  ('make', 'credit-control'): 9,
#  ('analytical skills', 'credit-control'): 7,
#  ('ar', 'credit-control'): 9,
#  ('sap', 'credit-control'): 10,
#  ('integration', 'credit-control'): 2,
#  ('fun', 'credit-control'): 2,
#  ('powerpoint', 'credit-control'): 5,
#  ('financial analysis', 'credit-control'): 4,
#  ('outlook', 'credit-control'): 4,
#  ('joy', 'credit-control'): 2,
#  ('erp systems', 'credit-control'): 4,
#  ('pivot table', 'credit-control'): 2,
#  ('vlookup', 'credit-control'): 2,
#  ('accounting systems', 'credit-control'): 7,
#  ('oracle', 'credit-control'): 4,
#  ('flex system', 'credit-control'): 4,
#  ('cfa', 'credit-control'): 3,
#  ('computer skills', 'credit-control'): 9,
#  ('frm', 'credit-control'): 3,
#  ('credit analysis', 'credit-control'): 3,
#  ('documentation', 'credit-control'): 2,
#  ('basic', 'credit-control'): 2,
#  ('chinese word processing', 'credit-control'): 3,
#  ('lcc', 'credit-control'): 3,
#  ('internal control', 'credit-control'): 4,
#  ('acca', 'credit-control'): 2,
#  ('dynamic', 'credit-control'): 2,
#  ('hkicpa', 'credit-control'): 2,
#  ('companies ordinance', 'credit-control'): 3,
#  ('python', 'credit-control'): 3,
#  ('vba', 'credit-control'): 4,
#  ('programming', 'credit-control'): 2,
#  ('information system', 'credit-control'): 1,
#  ('pc applications', 'credit-control'): 1,
#  ('microsoft office', 'credit-control'): 1,
#  ('pos system', 'credit-control'): 1,
#  ('flex accounting', 'credit-control'): 2,
#  ('processing', 'credit-control'): 3,
#  ('management reports', 'credit-control'): 2,
#  ('sales support', 'credit-control'): 1,
#  ('scheme', 'credit-control'): 1,
#  ('project management', 'credit-control'): 1,
#  ('acumen', 'credit-control'): 3,
#  ('pc knowledge', 'credit-control'): 1,
#  ('no', 'credit-control'): 1,
#  ('html', 'credit-control'): 1,
#  ('cpa', 'credit-control'): 2,
#  ('pc', 'credit-control'): 1,
#  ('accounting softwares', 'credit-control'): 1,
#  ('hkis', 'credit-control'): 1,
#  ('maintenance', 'credit-control'): 3,
#  ('rics', 'credit-control'): 1,
#  ('facilities management', 'credit-control'): 1,
#  ('billing system', 'credit-control'): 1,
#  ('c', 'credit-control'): 1,
#  ('bloomberg', 'credit-control'): 1,
#  ('microsoft excel', 'financial-analyst'): 41,
#  ('sap', 'financial-analyst'): 17,
#  ('erp', 'financial-analyst'): 5,
#  ('microsoft office suite', 'financial-analyst'): 24,
#  ('hkicpa', 'financial-analyst'): 18,
#  ('flex system', 'financial-analyst'): 2,
#  ('prc accounting', 'financial-analyst'): 3,
#  ('acumen', 'financial-analyst'): 11,
#  ('ifrs', 'financial-analyst'): 4,
#  ('professional qualifications', 'financial-analyst'): 2,
#  ('analysis', 'financial-analyst'): 22,
#  ('powerpoint', 'financial-analyst'): 26,
#  ('focus', 'financial-analyst'): 5,
#  ('data analytics', 'financial-analyst'): 4,
#  ('problem solving skills', 'financial-analyst'): 8,
#  ('acca', 'financial-analyst'): 11,
#  ('plus', 'financial-analyst'): 30,
#  ('cfa', 'financial-analyst'): 5,
#  ('financial analytical skills', 'financial-analyst'): 4,
#  ('analytical skills', 'financial-analyst'): 9,
#  ('cpa', 'financial-analyst'): 20,
#  ('financial analysis', 'financial-analyst'): 12,
#  ('sql', 'financial-analyst'): 4,
#  ('microsoft powerpoint', 'financial-analyst'): 2,
#  ('oracle', 'financial-analyst'): 6,
#  ('hkfrs', 'financial-analyst'): 2,
#  ('word', 'financial-analyst'): 8,
#  ('fmcg industry', 'financial-analyst'): 4,
#  ('pc', 'financial-analyst'): 4,
#  ('microsoft word', 'financial-analyst'): 5,
#  ('pe', 'financial-analyst'): 1,
#  ('bi', 'financial-analyst'): 6,
#  ('code', 'financial-analyst'): 2,
#  ('tableau', 'financial-analyst'): 6,
#  ('marco', 'financial-analyst'): 2,
#  ('r', 'financial-analyst'): 2,
#  ('salesforce', 'financial-analyst'): 2,
#  ('business intelligence', 'financial-analyst'): 5,
#  ('accounting systems', 'financial-analyst'): 7,
#  ('project management', 'financial-analyst'): 2,
#  ('erp systems', 'financial-analyst'): 5,
#  ('computer skills', 'financial-analyst'): 3,
#  ('internal control', 'financial-analyst'): 5,
#  ('chinese word processing', 'financial-analyst'): 4,
#  ('basic', 'financial-analyst'): 2,
#  ('ap', 'financial-analyst'): 2,
#  ('no', 'financial-analyst'): 3,
#  ('html', 'financial-analyst'): 2,
#  ('make', 'financial-analyst'): 3,
#  ('processing', 'financial-analyst'): 2,
#  ('microsoft office', 'financial-analyst'): 3,
#  ('xero', 'financial-analyst'): 1,
#  ('pos', 'financial-analyst'): 2,
#  ('vendor', 'financial-analyst'): 1,
#  ('documentation', 'financial-analyst'): 1,
#  ('dynamic', 'financial-analyst'): 4,
#  ('lcc', 'financial-analyst'): 1,
#  ('pc knowledge', 'financial-analyst'): 1,
#  ('vba', 'financial-analyst'): 2,
#  ('business management', 'financial-analyst'): 2,
#  ('sizable companies', 'financial-analyst'): 2,
#  ('mobile', 'financial-analyst'): 1,
#  ('workshops', 'financial-analyst'): 1,
#  ('spreadsheet', 'financial-analyst'): 1,
#  ('oracle system', 'financial-analyst'): 1,
#  ('scheme', 'financial-analyst'): 1,
#  ('management reports', 'financial-analyst'): 1,
#  ('writing skills', 'financial-analyst'): 1,
#  ('whatsapp', 'financial-analyst'): 1,
#  ('rapid', 'financial-analyst'): 1,
#  ('acca', 'taxation'): 15,
#  ('plus', 'taxation'): 12,
#  ('chinese word processing', 'taxation'): 5,
#  ('cpa', 'taxation'): 8,
#  ('dynamic', 'taxation'): 11,
#  ('microsoft office suite', 'taxation'): 12,
#  ('microsoft excel', 'taxation'): 29,
#  ('java', 'taxation'): 3,
#  ('word', 'taxation'): 12,
#  ('powerpoint', 'taxation'): 9,
#  ('analytical skills', 'taxation'): 7,
#  ('sql', 'taxation'): 5,
#  ('system design', 'taxation'): 3,
#  ('programming', 'taxation'): 3,
#  ('mathematics', 'taxation'): 3,
#  ('c#', 'taxation'): 3,
#  ('project management', 'taxation'): 7,
#  ('agile', 'taxation'): 2,
#  ('hkicpa', 'taxation'): 24,
#  ('documentation', 'taxation'): 6,
#  ('accounting systems', 'taxation'): 2,
#  ('sap', 'taxation'): 5,
#  ('crs', 'taxation'): 4,
#  ('microsoft office', 'taxation'): 7,
#  ('data analytics', 'taxation'): 5,
#  ('fatca', 'taxation'): 4,
#  ('exchange', 'taxation'): 3,
#  ('vba', 'taxation'): 2,
#  ('server', 'taxation'): 2,
#  ('bi', 'taxation'): 3,
#  ('presentations', 'taxation'): 3,
#  ('make', 'taxation'): 4,
#  ('erp', 'taxation'): 4,
#  ('databases', 'taxation'): 2,
#  ('alteryx', 'taxation'): 2,
#  ('integration', 'taxation'): 2,
#  ('focus', 'taxation'): 2,
#  ('oracle', 'taxation'): 4,
#  ('analysis', 'taxation'): 9,
#  ('ifrs', 'taxation'): 1,
#  ('quickbooks', 'taxation'): 1,
#  ('accounting and reporting software', 'taxation'): 1,
#  ('tableau', 'taxation'): 1,
#  ('erp systems', 'taxation'): 4,
#  ('pe', 'taxation'): 1,
#  ('problem solving skills', 'taxation'): 7,
#  ('microsoft word', 'taxation'): 3,
#  ('processing', 'taxation'): 4,
#  ('basic', 'taxation'): 4,
#  ('goal', 'taxation'): 2,
#  ('writing skills', 'taxation'): 2,
#  ('r&d', 'taxation'): 2,
#  ('focal', 'taxation'): 2,
#  ('hong kong institute of certified public accountants', 'taxation'): 2,
#  ('scheme', 'taxation'): 3,
#  ('flex accounting', 'taxation'): 2,
#  ('computer skills', 'taxation'): 3,
#  ('system implementation', 'taxation'): 1,
#  ('prc accounting', 'taxation'): 2,
#  ('pc knowledge', 'taxation'): 2,
#  ('outlook', 'taxation'): 1,
#  ('management reports', 'taxation'): 2,
#  ('no', 'taxation'): 3,
#  ('small', 'taxation'): 3,
#  ('flex system', 'taxation'): 2,
#  ('simple', 'taxation'): 1,
#  ('cobra', 'taxation'): 1,
#  ('sizable companies', 'taxation'): 1,
#  ('companies ordinance', 'taxation'): 1,
#  ('frr', 'taxation'): 1,
#  ('professional qualifications', 'taxation'): 2,
#  ('financial analysis', 'taxation'): 1,
#  ('gm', 'taxation'): 1,
#  ('hkfrs', 'taxation'): 1,
#  ('peachtree', 'taxation'): 1,
#  ('myob', 'taxation'): 1,
#  ('hkma', 'taxation'): 1,
#  ('accounting softwares', 'taxation'): 1,
#  ('c', 'taxation'): 1,
#  ...}
