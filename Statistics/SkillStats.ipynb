# %%
'''
This script generates **skill_update.txt** and **skill_compare.txt**.
Input:
    1. New database of jobs
    2. *skill.txt*
Output:
    1. *skill_update.txt*
    2. *skill_compare.txt*
'''
# Out:
# '\nThis script generates **skill_update.txt** and **skill_compare.txt**.\nInput:\n    1. New database of jobs\n    2. *skill.txt*\nOutput:\n    1. *skill_update.txt*\n    2. *skill_compare.txt*\n'

# %%
import pandas as pd

# %%
# insert new data
jobs = pd.read_json("support/data.json")

# %%
# record new data
data = []
for i in range(len(jobs)):
    data.append(jobs['requirements'][i]['hard_skills'])

count = {}
for i in range(len(data)):
    for s in data[i]:
        count[s] = count.get(s, 0) + 1

file = open("support/skill_update.txt", 'w') 
for k, v in count.items():
    file.write(str(k) + ': ' + str(v) + '\n')
file.close()

# %%
# load old record
old_count = {}
file = open("support/skill.txt", 'r')
for l in file.readlines():
    l = l.strip()
    k = l.split(': ')[0]
    v = l.split(': ')[1]
    old_count[k] = int(v)
file.close()

# %%
# compare two records
compare_dict = {}
for k, v in count.items():
    if k in old_count and count[k] != old_count[k]:
        compare_dict[k] = (count[k] - old_count[k]) / old_count[k]
compare_list = sorted(compare_dict.items(), key=lambda x: x[1], reverse=True)

file = open("support/skill_compare.txt", 'w')
for r in compare_list:
    file.write(r[0] + ': ' + ("%.2f" % (r[1] * 100)) + '%' + '\n')
file.close()

# %%
# output
compare_list
# Out:
# [('microsoft office suite', 125.73684210526316),
#  ('microsoft excel', 83.6590909090909),
#  ('in-design', 32.166666666666664),
#  ('accounting softwares', 21.5),
#  ('crypto currency', 19.0),
#  ('microsoft powerpoint', 16.25),
#  ('microsoft word', 10.742857142857142),
#  ('accounting systems', 9.222222222222221),
#  ('airlines', 7.833333333333333),
#  ('hong kong driving licence', 7.0),
#  ('problem solving skills', 6.877862595419847),
#  ('erp systems', 6.5),
#  ('web apps', 6.0),
#  ('dbms', 6.0),
#  ('customer journeys', 5.0),
#  ('ms sql', 4.444444444444445),
#  ('adobe acrobat', 4.0),
#  ('c4d', 4.0),
#  ('computing platforms', 4.0),
#  ('computer skills', 3.897590361445783),
#  ('the hong kong institution of engineers', 3.5),
#  ('oracle erp', 3.5),
#  ('web projects', 3.0),
#  ('printers', 3.0),
#  ('business software', 3.0),
#  ('linux platforms', 3.0),
#  ('unified communication', 3.0),
#  ('web application firewall', 3.0),
#  ('system upgrades', 3.0),
#  ('gpo', 3.0),
#  ('after effects', 2.981818181818182),
#  ('aamlp', 2.5),
#  ('technical analysis', 2.3333333333333335),
#  ('sfo', 2.3076923076923075),
#  ('flex system', 2.25),
#  ('mac environment', 2.2),
#  ('loan products', 2.2),
#  ('fire services system', 2.0),
#  ('building and a&a works', 2.0),
#  ('plumbing and drainage system', 2.0),
#  ('knowledge of hvac', 2.0),
#  ('electrical and lighting system', 2.0),
#  ('construction site safety requirements', 2.0),
#  ('3d modelling', 2.0),
#  ('hkfrs', 2.0),
#  ('crypto', 2.0),
#  ('ecc', 2.0),
#  ('sehk', 2.0),
#  ('association of chartered certified accountants', 2.0),
#  ('financial analytical skills', 2.0),
#  ('web graphics', 2.0),
#  ('visual effects', 2.0),
#  ('vocational certificate', 2.0),
#  ('it technologies', 2.0),
#  ('windows 10', 2.0),
#  ('sfc rules', 2.0),
#  ('web framework', 2.0),
#  ('web presence', 2.0),
#  ('airworthiness', 2.0),
#  ('euc', 2.0),
#  ('aircraft systems', 2.0),
#  ('airflow', 2.0),
#  ('hksfc', 2.0),
#  ('securities laws', 2.0),
#  ('know your customer', 2.0),
#  ('litigation process', 2.0),
#  ('investment products', 1.9473684210526316),
#  ('hyper-v', 1.875),
#  ('mcsa', 1.8571428571428572),
#  ('jenkins', 1.8461538461538463),
#  ('computer systems', 1.8333333333333333),
#  ('peachtree', 1.75),
#  ('microservices', 1.75),
#  ('server', 1.7383177570093458),
#  ('vc', 1.7142857142857142),
#  ('problem solving capabilities', 1.6666666666666667),
#  ('container', 1.6666666666666667),
#  ('word processing', 1.6666666666666667),
#  ('billing system', 1.6666666666666667),
#  ('it knowledge', 1.6),
#  ('shopify', 1.5833333333333333),
#  ('flash', 1.5454545454545454),
#  ('analytics tools', 1.5333333333333334),
#  ('adwords', 1.5238095238095237),
#  ('adobe creative suite', 1.511111111111111),
#  ('bim modelling', 1.5),
#  ('bms', 1.5),
#  ('accpac', 1.5),
#  ('alteryx', 1.5),
#  ('frr', 1.5),
#  ('salesforce', 1.5),
#  ('animation and video editing', 1.5),
#  ('luxury industry', 1.5),
#  ('public cloud platforms', 1.5),
#  ('data storage', 1.5),
#  ('web application security', 1.5),
#  ('banking practice', 1.5),
#  ('ms sql server', 1.4615384615384615),
#  ('web analytics', 1.4545454545454546),
#  ('wi-fi', 1.4),
#  ('writing skills', 1.3904761904761904),
#  ('frm', 1.375),
#  ('sizable companies', 1.368421052631579),
#  ('data mining', 1.3529411764705883),
#  ('typewriting', 1.3333333333333333),
#  ('adobe cs', 1.3333333333333333),
#  ('venture capital', 1.3333333333333333),
#  ('web server', 1.3333333333333333),
#  ('cyber security', 1.3214285714285714),
#  ('analytical skills', 1.313868613138686),
#  ('import and export', 1.3076923076923077),
#  ('management reports', 1.3),
#  ('spreadsheet', 1.3),
#  ('databases', 1.2950819672131149),
#  ('acca', 1.2947368421052632),
#  ('macro', 1.2857142857142858),
#  ('system design', 1.2857142857142858),
#  ('vpn', 1.28),
#  ('hkicpa', 1.2672413793103448),
#  ('active directory', 1.2666666666666666),
#  ('web-based applications', 1.25),
#  ('application system', 1.25),
#  ('struts', 1.25),
#  ('computer operation knowledge', 1.25),
#  ('qlikview', 1.25),
#  ('c#', 1.2380952380952381),
#  ('solidworks', 1.2352941176470589),
#  ('tcp', 1.2307692307692308),
#  ('web development', 1.225),
#  ('ip', 1.2222222222222223),
#  ('adobe premiere pro', 1.2222222222222223),
#  ('dns', 1.2105263157894737),
#  ('hkis', 1.2),
#  ('visual communication', 1.2),
#  ('bloomberg', 1.1944444444444444),
#  ('web technologies', 1.1818181818181819),
#  ('pc literate', 1.1818181818181819),
#  ('credit analysis', 1.1785714285714286),
#  ('agile', 1.173913043478261),
#  ('apache', 1.1666666666666667),
#  ('visual design', 1.1578947368421053),
#  ('o365', 1.1578947368421053),
#  ('firewall', 1.1481481481481481),
#  ('sap', 1.146153846153846),
#  ('microsoft applications', 1.1428571428571428),
#  ('project management professional', 1.1428571428571428),
#  ('cft', 1.1428571428571428),
#  ('outlook', 1.1401273885350318),
#  ('pmp', 1.1333333333333333),
#  ('google analytics', 1.1325301204819278),
#  ('presentation skill', 1.1320754716981132),
#  ('aws', 1.127659574468085),
#  ('documentation', 1.125984251968504),
#  ('acrobat', 1.125),
#  ('visual merchandising', 1.125),
#  ('infrastructure support', 1.125),
#  ('network administration', 1.125),
#  ('sales support', 1.12),
#  ('web application development', 1.1176470588235294),
#  ('sql', 1.1173708920187793),
#  ('web design', 1.1162790697674418),
#  ('premiere', 1.1136363636363635),
#  ('vmware', 1.1111111111111112),
#  ('iiqe', 1.1111111111111112),
#  ('os', 1.105263157894737),
#  ('typing', 1.1020408163265305),
#  ('ccass', 1.1),
#  ('pos', 1.0952380952380953),
#  ('chinese word processing', 1.0941915227629513),
#  ('hksi', 1.0930232558139534),
#  ('security personnel permit', 1.0909090909090908),
#  ('pc knowledge', 1.0902255639097744),
#  ('oracle', 1.0869565217391304),
#  ('android', 1.08),
#  ('amazon', 1.0769230769230769),
#  ('java', 1.0751445086705202),
#  ('video editing', 1.075),
#  ('power point', 1.0740740740740742),
#  ('ccnp', 1.0731707317073171),
#  ('cpa', 1.0683229813664596),
#  ('wan', 1.0666666666666667),
#  ('dynamic', 1.0597014925373134),
#  ('pe', 1.0555555555555556),
#  ('private equity', 1.0454545454545454),
#  ('words', 1.0444444444444445),
#  ('web', 1.0398406374501992),
#  ('data management', 1.0384615384615385),
#  ('order processing', 1.0344827586206897),
#  ('ccna', 1.0338983050847457),
#  ('deployment', 1.0307692307692307),
#  ('e-commerce', 1.0262008733624455),
#  ('vlookup', 1.0232558139534884),
#  ('bi', 1.0217391304347827),
#  ('word', 1.0163111668757843),
#  ('mobile', 1.013840830449827),
#  ('azure', 1.0135135135135136),
#  ('microsoft office', 1.0059701492537314),
#  ('certificate of registration of electrical worker', 1.0),
#  ('restful api', 1.0),
#  ('cctv', 1.0),
#  ('hong kong construction and building related legislations', 1.0),
#  ('submission process', 1.0),
#  ('elv system', 1.0),
#  ('av system', 1.0),
#  ('graphics', 1.0),
#  ('vendor', 1.0),
#  ('ajax', 1.0),
#  ('web services', 1.0),
#  ('system implementation', 1.0),
#  ('hong kong institute of certified public accountants', 1.0),
#  ('erp', 1.0),
#  ('mpf regulations', 1.0),
#  ('chinese input', 1.0),
#  ('pivot table', 1.0),
#  ('logical skills', 1.0),
#  ('six sigma', 1.0),
#  ('statistical analysis', 1.0),
#  ('seo', 1.0),
#  ('adobe xd', 1.0),
#  ('animation software', 1.0),
#  ('animate', 1.0),
#  ('sugar', 1.0),
#  ('first aid', 1.0),
#  ('router', 1.0),
#  ('git', 1.0),
#  ('web metrics', 1.0),
#  ('chartered financial analyst', 1.0),
#  ('spring', 1.0),
#  ('3pl management', 1.0),
#  ('mobile device', 1.0),
#  ('sfc license', 1.0),
#  ('reporting systems', 1.0),
#  ('bank documents', 1.0),
#  ('web traffic', 1.0),
#  ('microsoft sql server', 1.0),
#  ('hibernate', 1.0),
#  ('wireless protocols', 1.0),
#  ('windows 7', 1.0),
#  ('microsoft exchange', 1.0),
#  ('huawei cloud', 1.0),
#  ('lync', 1.0),
#  ('web browsers', 1.0),
#  ('basic it knowledge', 1.0),
#  ('cisco certified network associate', 1.0),
#  ('ruby on rails', 1.0),
#  ('acams', 1.0),
#  ('credit processing', 1.0),
#  ('incoming and outgoing swift payments', 1.0),
#  ('presentations', 0.9902912621359223),
#  ('financial analysis', 0.9827586206896551),
#  ('itil', 0.98),
#  ('python', 0.9770114942528736),
#  ('powerpoint', 0.9762470308788599),
#  ('pc applications', 0.9753086419753086),
#  ('business intelligence', 0.9714285714285714),
#  ('javascript', 0.9662162162162162),
#  ('hkie', 0.9642857142857143),
#  ('sdlc', 0.9642857142857143),
#  ('react native', 0.9629629629629629),
#  ('adobe illustrator', 0.9615384615384616),
#  ('multimedia', 0.9545454545454546),
#  ('pl', 0.9545454545454546),
#  ('linux', 0.9534883720930233),
#  ('php', 0.95),
#  ('web applications', 0.9411764705882353),
#  ('office 365', 0.9411764705882353),
#  ('vba', 0.9367088607594937),
#  ('mcse', 0.9302325581395349),
#  ('facebook', 0.9290322580645162),
#  ('final cut pro', 0.9259259259259259),
#  ('wechat', 0.9259259259259259),
#  ('whatsapp', 0.9166666666666666),
#  ('plc', 0.9166666666666666),
#  ('jquery', 0.9166666666666666),
#  ('aml', 0.9166666666666666),
#  ('hong kong employment ordinance', 0.9166666666666666),
#  ('integration', 0.9134615384615384),
#  ('analysis', 0.9134199134199135),
#  ('programming', 0.9126984126984127),
#  ('creative design', 0.9090909090909091),
#  ('server administration', 0.9090909090909091),
#  ('windows server', 0.9090909090909091),
#  ('html', 0.9060402684563759),
#  ('illustration', 0.9047619047619048),
#  ('c++', 0.9038461538461539),
#  ('illustrator', 0.9014084507042254),
#  ('ai', 0.9008264462809917),
#  ('anti-money laundering', 0.9),
#  ('bookings', 0.9),
#  ('data analytics', 0.8979591836734694),
#  ('fmcg industry', 0.8936170212765957),
#  ('adobe photoshop', 0.8928571428571429),
#  ('pc', 0.8904109589041096),
#  ('ms windows', 0.8888888888888888),
#  ('visual basic', 0.8888888888888888),
#  ('business management', 0.8878504672897196),
#  ('data warehouse', 0.8846153846153846),
#  ('tableau', 0.8833333333333333),
#  ('information system', 0.8780487804878049),
#  ('flex accounting', 0.875),
#  ('r', 0.8727272727272727),
#  ('css', 0.8699186991869918),
#  ('cdd', 0.8666666666666667),
#  ('office software', 0.8666666666666667),
#  ('devops', 0.8653846153846154),
#  ('dreamweaver', 0.8636363636363636),
#  ('photoshop', 0.862144420131291),
#  ('blockchain', 0.8620689655172413),
#  ('project management', 0.8613707165109035),
#  ('acumen', 0.861244019138756),
#  ('ifrs', 0.8571428571428571),
#  ('ar', 0.8571428571428571),
#  ('citrix', 0.8571428571428571),
#  ('wordpress', 0.8529411764705882),
#  ('3d software', 0.85),
#  ('aircraft', 0.8484848484848485),
#  ('ap', 0.8461538461538461),
#  ('premiere pro', 0.84375),
#  ('professional qualifications', 0.8426966292134831),
#  ('switch', 0.84),
#  ('prc manufacturing', 0.8333333333333334),
#  ('sd-wan', 0.8333333333333334),
#  ('hardware', 0.8309859154929577),
#  ('react', 0.8289473684210527),
#  ('iiqe paper', 0.8260869565217391),
#  ('internal control', 0.825),
#  ('maintenance', 0.8209366391184573),
#  ('kyc', 0.8205128205128205),
#  ('adobe indesign', 0.8181818181818182),
#  ('lcc', 0.8157894736842105),
#  ('translation', 0.8021978021978022),
#  ('adobe', 0.8),
#  ('companies ordinance', 0.8),
#  ('marketing skills', 0.8),
#  ('service level agreement', 0.8),
#  ('safe', 0.7962962962962963),
#  ('pc operations', 0.7916666666666666),
#  ('r&d', 0.78125),
#  ('angular', 0.7777777777777778),
#  ('myob', 0.7777777777777778),
#  ('xero', 0.7777777777777778),
#  ('account opening', 0.7777777777777778),
#  ('hkma', 0.7777777777777778),
#  ('exchange', 0.7721518987341772),
#  ('microsoft project', 0.7692307692307693),
#  ('chinese and english word processing', 0.7692307692307693),
#  ('cfa', 0.7640449438202247),
#  ('database programming', 0.75),
#  ('rics', 0.75),
#  ('airports', 0.75),
#  ('briefings', 0.75),
#  ('rpa', 0.75),
#  ('hkma regulatory reporting', 0.75),
#  ('autocad', 0.7464285714285714),
#  ('workshops', 0.7397260273972602),
#  ('lean', 0.7368421052631579),
#  ('sla', 0.7333333333333333),
#  ('sem', 0.7301587301587301),
#  ('green card', 0.7142857142857143),
#  ('animal work', 0.7142857142857143),
#  ('c', 0.7043478260869566),
#  ('marco', 0.7),
#  ('adobe premiere', 0.7),
#  ('hkicm', 0.6666666666666666),
#  ('sketch up', 0.6666666666666666),
#  ('flex', 0.6666666666666666),
#  ('supply planning', 0.6666666666666666),
#  ('adobe cc', 0.6666666666666666),
#  ('publisher', 0.6666666666666666),
#  ('numerical skills', 0.6666666666666666),
#  ('shipping document', 0.6666666666666666),
#  ('antivirus', 0.6666666666666666),
#  ('iis', 0.6666666666666666),
#  ('jsf', 0.6666666666666666),
#  ('aml screening', 0.6666666666666666),
#  ('securities and futures ordinance', 0.64),
#  ('data visualization', 0.6304347826086957),
#  ('cad', 0.6274509803921569),
#  ('adobe software', 0.625),
#  ('facilities management', 0.62),
#  ('chinese wp', 0.6153846153846154),
#  ('hvac', 0.6111111111111112),
#  ('security management', 0.6),
#  ('mammography', 0.6),
#  ('web & mobile', 0.6),
#  ('operation support', 0.5833333333333334),
#  ('crs', 0.5714285714285714),
#  ('animal studies', 0.5714285714285714),
#  ('oracle system', 0.5555555555555556),
#  ('3ds max', 0.55),
#  ('prc accounting', 0.5454545454545454),
#  ('merchandizing', 0.5454545454545454),
#  ('sap2000', 0.5),
#  ('ciob', 0.5),
#  ('fms', 0.5),
#  ('fatca', 0.5),
#  ('customer due diligence', 0.5),
#  ('demand planning', 0.5),
#  ('educational projects', 0.5),
#  ('visual editing', 0.5),
#  ('execution strategy', 0.5),
#  ('budget management', 0.5),
#  ('animal welfare', 0.5),
#  ('data network', 0.5),
#  ('access points', 0.5),
#  ('financial risk manager', 0.5),
#  ('animal science', 0.5),
#  ('animal handling', 0.5),
#  ('dexa', 0.5),
#  ('amazon web services', 0.5),
#  ('airframe', 0.5),
#  ('data manipulation', 0.5),
#  ('credit analytical skills', 0.5),
#  ('sketchup', 0.4838709677419355),
#  ('ansible', 0.45454545454545453),
#  ('bim', 0.4426229508196721),
#  ('maya', 0.42857142857142855),
#  ('network management', 0.42857142857142855),
#  ('revit', 0.4),
#  ('web pages', 0.4),
#  ('vs', 0.4),
#  ('nas', 0.4),
#  ('android development', 0.4),
#  ('dcass', 0.4),
#  ('garment industry', 0.375),
#  ('sccm', 0.375),
#  ('etabs', 0.3333333333333333),
#  ('first aid certificate', 0.3333333333333333),
#  ('quickbooks', 0.3333333333333333),
#  ('pos system', 0.3333333333333333),
#  ('creative suite', 0.3333333333333333),
#  ('3dmax', 0.3333333333333333),
#  ('scrum framework', 0.3333333333333333),
#  ('hksi paper', 0.3333333333333333),
#  ('web api', 0.3333333333333333),
#  ('centos', 0.3333333333333333),
#  ('red hat', 0.3333333333333333),
#  ('application server', 0.3333333333333333),
#  ('ra type', 0.3333333333333333),
#  ('mac os', 0.3),
#  ('cloud environment', 0.3),
#  ('ems', 0.2857142857142857),
#  ('android sdk', 0.2857142857142857),
#  ('aircraft maintenance', 0.2857142857142857),
#  ('mhkie', 0.2777777777777778),
#  ('rhino', 0.2608695652173913),
#  ('chinese & english typing', 0.25),
#  ('virtualization technology', 0.25),
#  ('animal husbandry', 0.25),
#  ('building information modelling', 0.16666666666666666),
#  ('design softwares', 0.16666666666666666),
#  ('revit architecture', -0.3333333333333333),
#  ('codes and regulations', -0.5),
#  ('realtime landscaping', -0.5)]
