# %%
'''
This script generates *skill.txt* and *skill_compare.txt* in *support/records/*.
Input:
    1. New database of jobs
    2. *skill'.txt*
Output:
    1. *skill.txt*
    2. *skill_compare.txt*
'''
# Out:
# "\nThis script generates *skill.txt* and *skill_compare.txt* in *support/records/*.\nInput:\n    1. New database of jobs\n    2. *skill'.txt*\nOutput:\n    1. *skill.txt*\n    2. *skill_compare.txt*\n"

# %%
import pandas as pd

# %%
# TODO: insert real data instead of demo data below
jobs = pd.read_json("support/data.json")

# %%
# record new data
data = []
for i in range(len(jobs)):
    data.append(jobs['requirements'][i]['hard_skills'])

count = {}
for i in range(len(data)):
    for s in data[i]:
        count[s] = count.get(s, 0) + 1

file = open("support/records/skill.txt", 'w') 
for k, v in count.items():
    file.write(str(k) + ': ' + str(v) + '\n')
file.close()

# %%
# load old record
old_count = {}
file = open("support/records/skill'.txt", 'r')
for l in file.readlines():
    l = l.strip()
    k = l.split(': ')[0]
    v = l.split(': ')[1]
    old_count[k] = int(v)
file.close()

# %%
# compare two records
compare_dict = {}
for k, v in count.items():
    if k in old_count and count[k] != old_count[k]:
        compare_dict[k] = (count[k] - old_count[k]) / old_count[k]
compare_list = sorted(compare_dict.items(), key=lambda x: x[1], reverse=True)

file = open("support/records/skill_compare.txt", 'w')
for r in compare_list:
    file.write(r[0] + ': ' + ("%.2f" % (r[1] * 100)) + '%' + '\n')
file.close()

# %%
# output
compare_list
# Out:
# [('ms based applications', 2.0),
#  ('pizza', 1.0),
#  ('web conferencing', 1.0),
#  ('mary', 1.0),
#  ('help desk support', 1.0),
#  ('web chat', 1.0),
#  ('stata', 1.0),
#  ('centos', 1.0),
#  ('web standards', 1.0),
#  ('android studio', 1.0),
#  ('web browsers', 1.0),
#  ('csh', 1.0),
#  ('awk', 1.0),
#  ('web application design', 1.0),
#  ('vsan', 1.0),
#  ('qdii', 1.0),
#  ('airports', 0.75),
#  ('bim modelling', 0.6666666666666666),
#  ('antivirus', 0.6666666666666666),
#  ('ecc', 0.5),
#  ('web products', 0.5),
#  ('compass', 0.5),
#  ('tutor', 0.5),
#  ('forth', 0.5),
#  ('it technologies', 0.5),
#  ('groovy', 0.5),
#  ('pure', 0.5),
#  ('customer journeys', 0.5),
#  ('financial risk manager', 0.5),
#  ('george', 0.5),
#  ('dexa', 0.5),
#  ('aircraft systems', 0.5),
#  ('airflow', 0.5),
#  ('banking laws', 0.5),
#  ('qfii', 0.5),
#  ('know your customer', 0.5),
#  ('litigation process', 0.5),
#  ('credit analytical skills', 0.5),
#  ('cloud environment', 0.4444444444444444),
#  ('hibernate', 0.42857142857142855),
#  ('building information modelling', 0.4),
#  ('dcass', 0.4),
#  ('flex system', 0.3684210526315789),
#  ('supply planning', 0.36363636363636365),
#  ('sr', 0.36363636363636365),
#  ('hkfrs', 0.3333333333333333),
#  ('alteryx', 0.3333333333333333),
#  ('creative suite', 0.3333333333333333),
#  ('3dmax', 0.3333333333333333),
#  ('hy', 0.3333333333333333),
#  ('hong kong driving licence', 0.3333333333333333),
#  ('scrum framework', 0.3333333333333333),
#  ('sfc license', 0.3333333333333333),
#  ('web traffic', 0.3333333333333333),
#  ('microsoft sql server', 0.3333333333333333),
#  ('business software', 0.3333333333333333),
#  ('mammography', 0.3333333333333333),
#  ('web & mobile', 0.3333333333333333),
#  ('web api', 0.3333333333333333),
#  ('web application firewall', 0.3333333333333333),
#  ('system upgrades', 0.3333333333333333),
#  ('informix', 0.3333333333333333),
#  ('ra type', 0.3333333333333333),
#  ('creative design', 0.3125),
#  ('visual basic', 0.3076923076923077),
#  ('customer due diligence', 0.2857142857142857),
#  ('financial analytical skills', 0.2857142857142857),
#  ('scratch', 0.2857142857142857),
#  ('windows 10', 0.2857142857142857),
#  ('computer operation knowledge', 0.2857142857142857),
#  ('internal control', 0.2807017543859649),
#  ('spreadsheet', 0.2777777777777778),
#  ('chill', 0.2727272727272727),
#  ('operation support', 0.26666666666666666),
#  ('data warehouse', 0.2564102564102564),
#  ('dynamo', 0.25),
#  ('flex', 0.25),
#  ('adobe cc', 0.25),
#  ('public cloud platforms', 0.25),
#  ('data storage', 0.25),
#  ('web application security', 0.25),
#  ('portable', 0.25),
#  ('inbound and outbound logistics', 0.25),
#  ('aml screening', 0.25),
#  ('spring', 0.24675324675324675),
#  ('pipelines', 0.23529411764705882),
#  ('charity', 0.23529411764705882),
#  ('business intelligence', 0.23214285714285715),
#  ('bim', 0.2222222222222222),
#  ('hkis', 0.2222222222222222),
#  ('web applications', 0.2222222222222222),
#  ('sccm', 0.2222222222222222),
#  ('animal studies', 0.2222222222222222),
#  ('system implementation', 0.21428571428571427),
#  ('infrastructure support', 0.21428571428571427),
#  ('salesforce', 0.21212121212121213),
#  ('revit', 0.21153846153846154),
#  ('mhkie', 0.21052631578947367),
#  ('cyber security', 0.2037037037037037),
#  ('red', 0.2),
#  ('sap2000', 0.2),
#  ('microsoft applications', 0.2),
#  ('logo', 0.2),
#  ('iiqe paper', 0.2),
#  ('hksi paper', 0.2),
#  ('labview', 0.2),
#  ('sas', 0.2),
#  ('ipl', 0.2),
#  ('cisco certified network associate', 0.2),
#  ('s3', 0.2),
#  ('aircraft', 0.19607843137254902),
#  ('shopify', 0.19230769230769232),
#  ('hope', 0.19047619047619047),
#  ('dc', 0.19047619047619047),
#  ('jquery', 0.1896551724137931),
#  ('anti-money laundering', 0.1875),
#  ('vc', 0.1875),
#  ('small', 0.18716577540106952),
#  ('clean', 0.18604651162790697),
#  ('ms sql server', 0.18518518518518517),
#  ('graphics', 0.18446601941747573),
#  ('business management', 0.18128654970760233),
#  ('itil', 0.17857142857142858),
#  ('react native', 0.17777777777777778),
#  ('adobe indesign', 0.17647058823529413),
#  ('web services', 0.17647058823529413),
#  ('mcsa', 0.17647058823529413),
#  ('os', 0.17647058823529413),
#  ('amazon', 0.17391304347826086),
#  ('web analytics', 0.17391304347826086),
#  ('qlikview', 0.17391304347826086),
#  ('ms windows', 0.1724137931034483),
#  ('macro', 0.17073170731707318),
#  ('database programming', 0.16666666666666666),
#  ('rics', 0.16666666666666666),
#  ('clips', 0.16666666666666666),
#  ('dns', 0.16666666666666666),
#  ('beta', 0.16666666666666666),
#  ('web apps', 0.16666666666666666),
#  ('mouse', 0.16666666666666666),
#  ('dbms', 0.16666666666666666),
#  ('web server', 0.16666666666666666),
#  ('android development', 0.16666666666666666),
#  ('aamlp', 0.16666666666666666),
#  ('frm', 0.16326530612244897),
#  ('code', 0.16243654822335024),
#  ('sfo', 0.16216216216216217),
#  ('planner', 0.16216216216216217),
#  ('financial analysis', 0.16161616161616163),
#  ('companies ordinance', 0.16129032258064516),
#  ('gap', 0.16129032258064516),
#  ('hvac', 0.16),
#  ('sem', 0.1595744680851064),
#  ('pc applications', 0.15942028985507245),
#  ('pos', 0.15789473684210525),
#  ('mathematics', 0.15789473684210525),
#  ('azure', 0.15503875968992248),
#  ('cfa', 0.15441176470588236),
#  ('cctv', 0.15384615384615385),
#  ('ajax', 0.15384615384615385),
#  ('io', 0.15384615384615385),
#  ('statistical analysis', 0.15384615384615385),
#  ('luxury industry', 0.15384615384615385),
#  ('data visualization', 0.15384615384615385),
#  ('bash', 0.15384615384615385),
#  ('r&d', 0.15151515151515152),
#  ('microsoft project', 0.15),
#  ('chinese and english word processing', 0.15),
#  ('ai', 0.15),
#  ('microsoft powerpoint', 0.15),
#  ('hong kong employment ordinance', 0.15),
#  ('analysis', 0.14904679376083188),
#  ('go', 0.14893617021276595),
#  ('mobile', 0.14566929133858267),
#  ('kyc', 0.14516129032258066),
#  ('video editing', 0.14482758620689656),
#  ('typing', 0.14444444444444443),
#  ('goal', 0.14432989690721648),
#  ('acumen', 0.14411764705882352),
#  ('ap', 0.14285714285714285),
#  ('android', 0.14285714285714285),
#  ('myob', 0.14285714285714285),
#  ('xero', 0.14285714285714285),
#  ('investment products', 0.14285714285714285),
#  ('word processing', 0.14285714285714285),
#  ('account opening', 0.14285714285714285),
#  ('chinese input', 0.14285714285714285),
#  ('data mining', 0.14285714285714285),
#  ('focal', 0.14285714285714285),
#  ('acc', 0.14285714285714285),
#  ('cool', 0.14285714285714285),
#  ('cg', 0.14285714285714285),
#  ('loan products', 0.14285714285714285),
#  ('printers', 0.14285714285714285),
#  ('abap', 0.14285714285714285),
#  ('microsoft exchange', 0.14285714285714285),
#  ('t-sql', 0.14285714285714285),
#  ('javascript', 0.1411764705882353),
#  ('microsoft office', 0.14091680814940577),
#  ('writing skills', 0.1409090909090909),
#  ('cpa', 0.1404109589041096),
#  ('vpn', 0.14),
#  ('airlines', 0.13978494623655913),
#  ('data management', 0.13978494623655913),
#  ('pc knowledge', 0.13934426229508196),
#  ('sql', 0.1388888888888889),
#  ('databases', 0.13821138211382114),
#  ('office 365', 0.13793103448275862),
#  ('firewall', 0.13725490196078433),
#  ('project management', 0.1359315589353612),
#  ('premiere pro', 0.1346153846153846),
#  ('autocad', 0.1345707656612529),
#  ('acrobat', 0.13333333333333333),
#  ('prc accounting', 0.13333333333333333),
#  ('marco', 0.13333333333333333),
#  ('matlab', 0.13333333333333333),
#  ('factor', 0.13333333333333333),
#  ('active directory', 0.13333333333333333),
#  ('web', 0.13274336283185842),
#  ('pivot table', 0.13253012048192772),
#  ('information system', 0.1323529411764706),
#  ('scheme', 0.13175675675675674),
#  ('pc operations', 0.13157894736842105),
#  ('power point', 0.13131313131313133),
#  ('dynamic', 0.13114754098360656),
#  ('lcc', 0.13114754098360656),
#  ('restful api', 0.13043478260869565),
#  ('final cut pro', 0.13043478260869565),
#  ('presentation skill', 0.13),
#  ('credit analysis', 0.12962962962962962),
#  ('swift', 0.12941176470588237),
#  ('exchange', 0.12903225806451613),
#  ('basic', 0.12898089171974522),
#  ('hkicpa', 0.12875536480686695),
#  ('chinese word processing', 0.12859560067681894),
#  ('problem solving skills', 0.12848551120831056),
#  ('focus', 0.12813370473537605),
#  ('vendor', 0.128),
#  ('sales support', 0.1276595744680851),
#  ('microsoft excel', 0.12742130750605327),
#  ('bi', 0.12727272727272726),
#  ('vmware', 0.1271186440677966),
#  ('server', 0.12692307692307692),
#  ('analytical skills', 0.12544378698224853),
#  ('microsoft office suite', 0.1252336448598131),
#  ('rapid', 0.125),
#  ('the hong kong institution of engineers', 0.125),
#  ('sap', 0.125),
#  ('private equity', 0.125),
#  ('oracle erp', 0.125),
#  ('windows server', 0.125),
#  ('application system', 0.125),
#  ('service level agreement', 0.125),
#  ('struts', 0.125),
#  ('animal handling', 0.125),
#  ('unix shell', 0.125),
#  ('aircraft maintenance', 0.125),
#  ('in-design', 0.12429378531073447),
#  ('after effects', 0.12307692307692308),
#  ('angular', 0.12280701754385964),
#  ('hkma', 0.12280701754385964),
#  ('html', 0.1225296442687747),
#  ('php', 0.1223021582733813),
#  ('words', 0.12195121951219512),
#  ('management reports', 0.12195121951219512),
#  ('aml', 0.12195121951219512),
#  ('pe', 0.12121212121212122),
#  ('jenkins', 0.12121212121212122),
#  ('hardware', 0.1206896551724138),
#  ('reason', 0.12048192771084337),
#  ('fun', 0.12),
#  ('linux', 0.12),
#  ('cdd', 0.12),
#  ('flash', 0.12),
#  ('ip', 0.12),
#  ('office software', 0.12),
#  ('rpa', 0.12),
#  ('kotlin', 0.12),
#  ('whatsapp', 0.1198501872659176),
#  ('facebook', 0.1198501872659176),
#  ('r', 0.11956521739130435),
#  ('plus', 0.11937059142702117),
#  ('wechat', 0.11827956989247312),
#  ('microsoft word', 0.11786038077969176),
#  ('analytics tools', 0.11764705882352941),
#  ('perl', 0.11764705882352941),
#  ('aws', 0.11731843575418995),
#  ('vba', 0.11678832116788321),
#  ('no', 0.11631663974151858),
#  ('pmp', 0.11627906976744186),
#  ('powerpoint', 0.11602951039570758),
#  ('word', 0.11597222222222223),
#  ('tcp', 0.11538461538461539),
#  ('rhino', 0.11538461538461539),
#  ('e-commerce', 0.11538461538461539),
#  ('vlookup', 0.11538461538461539),
#  ('computer skills', 0.11522633744855967),
#  ('java', 0.11490683229813664),
#  ('erp', 0.11450381679389313),
#  ('make', 0.11403508771929824),
#  ('ms sql', 0.11363636363636363),
#  ('google analytics', 0.11320754716981132),
#  ('programming', 0.11316397228637413),
#  ('fmcg industry', 0.1125),
#  ('adobe photoshop', 0.11188811188811189),
#  ('agile', 0.1111111111111111),
#  ('sketch up', 0.1111111111111111),
#  ('bms', 0.1111111111111111),
#  ('system design', 0.1111111111111111),
#  ('maya', 0.1111111111111111),
#  ('adobe premiere pro', 0.1111111111111111),
#  ('publisher', 0.1111111111111111),
#  ('ease', 0.1111111111111111),
#  ('mobile device', 0.1111111111111111),
#  ('network management', 0.1111111111111111),
#  ('powershell', 0.1111111111111111),
#  ('adobe', 0.10869565217391304),
#  ('accounting systems', 0.10843373493975904),
#  ('presentations', 0.10810810810810811),
#  ('translation', 0.10810810810810811),
#  ('visual design', 0.10810810810810811),
#  ('processing', 0.10787172011661808),
#  ('adobe creative suite', 0.10784313725490197),
#  ('tableau', 0.10784313725490197),
#  ('wan', 0.10714285714285714),
#  ('data analytics', 0.10714285714285714),
#  ('seo', 0.10714285714285714),
#  ('mcse', 0.10666666666666667),
#  ('integration', 0.10555555555555556),
#  ('chinese wp', 0.10526315789473684),
#  ('wordpress', 0.10526315789473684),
#  ('ccass', 0.10526315789473684),
#  ('simple', 0.1044776119402985),
#  ('workshops', 0.10434782608695652),
#  ('erp systems', 0.10429447852760736),
#  ('pc', 0.104),
#  ('container', 0.10344827586206896),
#  ('pl', 0.10256410256410256),
#  ('safe', 0.10227272727272728),
#  ('devops', 0.10227272727272728),
#  ('illustrator', 0.10204081632653061),
#  ('outlook', 0.10163934426229508),
#  ('c#', 0.1015625),
#  ('acca', 0.10101010101010101),
#  ('ccna', 0.10091743119266056),
#  ('professional qualifications', 0.10067114093959731),
#  ('deployment', 0.1),
#  ('lean', 0.1),
#  ('visual communication', 0.1),
#  ('garment industry', 0.1),
#  ('microservices', 0.1),
#  ('multimedia', 0.09787234042553192),
#  ('accounting softwares', 0.0975609756097561),
#  ('web design', 0.0963855421686747),
#  ('python', 0.09554140127388536),
#  ('sketchup', 0.09523809523809523),
#  ('plc', 0.09523809523809523),
#  ('css', 0.09523809523809523),
#  ('hyper-v', 0.09523809523809523),
#  ('photoshop', 0.09383033419023136),
#  ('order processing', 0.09259259259259259),
#  ('c', 0.09192200557103064),
#  ('3d modelling', 0.09090909090909091),
#  ('crypto', 0.09090909090909091),
#  ('web technologies', 0.09090909090909091),
#  ('animate', 0.09090909090909091),
#  ('pc literate', 0.09090909090909091),
#  ('web application development', 0.09090909090909091),
#  ('animal work', 0.09090909090909091),
#  ('wi-fi', 0.09090909090909091),
#  ('id', 0.08928571428571429),
#  ('inform', 0.08928571428571429),
#  ('documentation', 0.08870967741935484),
#  ('3d software', 0.08823529411764706),
#  ('six sigma', 0.08695652173913043),
#  ('batch', 0.08695652173913043),
#  ('react', 0.0859375),
#  ('adobe xd', 0.08571428571428572),
#  ('maintenance', 0.08538587848932677),
#  ('visual merchandising', 0.0851063829787234),
#  ('hksi', 0.08433734939759036),
#  ('ifrs', 0.08333333333333333),
#  ('sla', 0.08333333333333333),
#  ('it knowledge', 0.08333333333333333),
#  ('citrix', 0.08333333333333333),
#  ('adwords', 0.08163265306122448),
#  ('o365', 0.07894736842105263),
#  ('hkie', 0.0784313725490196),
#  ('sdlc', 0.0784313725490196),
#  ('cad', 0.07792207792207792),
#  ('adobe illustrator', 0.07746478873239436),
#  ('certificate of registration of electrical worker', 0.07692307692307693),
#  ('oracle system', 0.07692307692307693),
#  ('router', 0.07692307692307693),
#  ('ml', 0.07692307692307693),
#  ('scala', 0.07692307692307693),
#  ('nas', 0.07692307692307693),
#  ('joy', 0.07407407407407407),
#  ('web development', 0.07228915662650602),
#  ('sizable companies', 0.07142857142857142),
#  ('oracle', 0.07142857142857142),
#  ('frr', 0.07142857142857142),
#  ('numerical skills', 0.07142857142857142),
#  ('cft', 0.07142857142857142),
#  ('iiqe', 0.07042253521126761),
#  ('switch', 0.06976744186046512),
#  ('3ds max', 0.06896551724137931),
#  ('typescript', 0.06896551724137931),
#  ('objective-c', 0.06896551724137931),
#  ('green card', 0.06666666666666667),
#  ('mac environment', 0.06666666666666667),
#  ('ansible', 0.06666666666666667),
#  ('c++', 0.06451612903225806),
#  ('git', 0.06329113924050633),
#  ('computer systems', 0.0625),
#  ('merchandizing', 0.0625),
#  ('ccnp', 0.0625),
#  ('spark', 0.0625),
#  ('network administration', 0.0625),
#  ('gm', 0.058823529411764705),
#  ('demand planning', 0.058823529411764705),
#  ('marketing skills', 0.058823529411764705),
#  ('nice', 0.05660377358490566),
#  ('solidworks', 0.05555555555555555),
#  ('mad', 0.05555555555555555),
#  ('bookings', 0.05555555555555555),
#  ('ar', 0.05405405405405406),
#  ('crypto currency', 0.05263157894736842),
#  ('facilities management', 0.05194805194805195),
#  ('dreamweaver', 0.05128205128205128),
#  ('server administration', 0.05),
#  ('peachtree', 0.047619047619047616),
#  ('security personnel permit', 0.045454545454545456),
#  ('max', 0.04),
#  ('bloomberg', 0.039473684210526314),
#  ('blockchain', 0.038461538461538464),
#  ('import and export', 0.034482758620689655),
#  ('premiere', 0.03333333333333333),
#  ('adobe premiere', 0.030303030303030304),
#  ('illustration', 0.02564102564102564)]
